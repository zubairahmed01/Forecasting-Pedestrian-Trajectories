# %%
# !cd ../. && python ./trainer_main.py \
--dataset eth \
--epochs 1200 \
--batch-size 64 \
--latent-dim 10 \
--d-learning-rate 1E-3 \
--g-learning-rate 1E-4 \
--unrolling-steps 1 \
--hidden-size 64 \
--n-social-features 3 \
--n-graph-attention-heads 4 \
--model socialWays \
--n-lstm-layers 1 \
--scale-data True \
--social-attention True \
--graph True \
--new-criterion True \
--info-loss-weight 0.9 \
--n-disc-code 2 \
--n-cont-code 2 \
--model-name-append full-10-12 \
--code-eval True \
--seed 1234
# Out:
# Using torch 2.0.1
# Is the GPU available? False
# Device cpu
# ===== START -->> Data and Time: 15-03-24, 10:49:41 ( Darwin - posix ) =====
# ----- printing args -----
# {   'batch_size': 64,
#     'c1h': False,
#     'code_eval': True,
#     'd_learning_rate': 0.001,
#     'dataset': 'eth',
#     'dataset_parser': 'socialWays',
#     'dataset_type': 'socialWays',
#     'epochs': 1200,
#     'g_learning_rate': 0.0001,
#     'graph': True,
#     'hidden_size': 64,
#     'info_loss_weight': 0.9,
#     'l1o': False,
#     'lambda_cont_code': 0.1,
#     'lambda_disc_code': 0.1,
#     'latent_dim': 10,
#     'lstm_decoder': False,
#     'model': 'socialWays',
#     'model_name_append': 'full-10-12',
#     'n_cont_code': 2,
#     'n_disc_code': 2,
#     'n_graph_attention_heads': 4,
#     'n_lstm_layers': 1,
#     'n_social_features': 3,
#     'new_criterion': True,
#     'nll': False,
#     'scale_data': True,
#     'seed': 1234,
#     'social_attention': True,
#     'unrolling_steps': 1}
# --x-- printing args --x--
# Model File For Training:  ./TRAJ/trained_models/socialWays/eth_sg_22_34_1200-bce-0.9_full-10-12_nec.pt
# Loading model from ./TRAJ/trained_models/socialWays/eth_sg_22_34_1200-bce-0.9_full-10-12_nec.pt
# model trained on: 10-12-23, 08:21:29
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/eth-8-12.npz  # Training samples:  1833
# ./TRAJ/processed/socialWays/eth-8-12.npz  # Test samples:  781
# Batched Test Dataset Creation time: 0 hour: 0 min: 1 sec
# Total Data Processing Time: 0 hour: 0 min: 1 sec
# Performing Code Evaluation on data...
# (Velocity, slope): Cont-1 = (0.003321, -0.002134) | Cont-2 = (-0.004937, 0.000732)
# (Velocity, slope): Cont-1 = (-0.001258, -0.002496) | Cont-2 = (-0.006692, 0.001219)
# (Velocity, slope): Cont-1 = (0.000079, -0.002480) | Cont-2 = (-0.007192, 0.001153)
# (Velocity, slope): Cont-1 = (-0.000679, -0.002563) | Cont-2 = (-0.007652, 0.001151)
# (Velocity, slope): Cont-1 = (-0.001182, -0.002755) | Cont-2 = (-0.008012, 0.001114)
# (Velocity, slope): Cont-1 = (-0.001805, -0.002922) | Cont-2 = (-0.008032, 0.001105)
# (Velocity, slope): Cont-1 = (-0.001683, -0.003046) | Cont-2 = (-0.007206, 0.001160)
# (Velocity, slope): Cont-1 = (-0.001929, -0.003197) | Cont-2 = (-0.006685, 0.001251)
# (Velocity, slope): Cont-1 = (-0.001658, -0.002687) | Cont-2 = (-0.005456, 0.000840)
# (Velocity, slope): Cont-1 = (-0.002658, -0.002109) | Cont-2 = (-0.004708, 0.000415)
# (Velocity, slope): Cont-1 = (-0.001862, -0.001643) | Cont-2 = (-0.005151, 0.000126)
# (Velocity, slope): Cont-1 = (-0.000708, -0.001252) | Cont-2 = (-0.005674, -0.000175)
# (Velocity, slope): Cont-1 = (0.001754, -0.001891) | Cont-2 = (-0.006484, -0.000256)
# (Velocity, slope): Cont-1 = (0.002799, -0.002703) | Cont-2 = (-0.006968, 0.000107)
# (Velocity, slope): Cont-1 = (0.001840, -0.003055) | Cont-2 = (-0.006688, 0.000315)
# (Velocity, slope): Cont-1 = (0.000696, -0.003292) | Cont-2 = (-0.006776, 0.000461)
# (Velocity, slope): Cont-1 = (-0.000537, -0.003060) | Cont-2 = (-0.005676, 0.000455)
# (Velocity, slope): Cont-1 = (-0.000594, -0.002885) | Cont-2 = (-0.004883, 0.000372)
# (Velocity, slope): Cont-1 = (-0.000685, -0.002709) | Cont-2 = (-0.004191, 0.000287)
# (Velocity, slope): Cont-1 = (-0.000738, -0.002547) | Cont-2 = (-0.003626, 0.000207)
# (Velocity, slope): Cont-1 = (-0.000213, -0.002482) | Cont-2 = (-0.003570, 0.000233)
# (Velocity, slope): Cont-1 = (0.000086, -0.002404) | Cont-2 = (-0.003618, 0.000255)
# (Velocity, slope): Cont-1 = (0.000005, -0.002327) | Cont-2 = (-0.003740, 0.000290)
# (Velocity, slope): Cont-1 = (-0.000134, -0.002259) | Cont-2 = (-0.003844, 0.000317)
# (Velocity, slope): Cont-1 = (-0.000250, -0.002198) | Cont-2 = (-0.003953, 0.000346)
# (Velocity, slope): Cont-1 = (-0.000436, -0.002155) | Cont-2 = (-0.004025, 0.000379)
# (Velocity, slope): Cont-1 = (-0.000886, -0.002125) | Cont-2 = (-0.003834, 0.000410)
# (Velocity, slope): Cont-1 = (-0.001502, -0.002107) | Cont-2 = (-0.003594, 0.000456)
# (Velocity, slope): Cont-1 = (-0.001601, -0.002067) | Cont-2 = (-0.003652, 0.000478)
# (Velocity, slope): Cont-1 = (-0.001727, -0.002034) | Cont-2 = (-0.003733, 0.000504)
# (Velocity, slope): Cont-1 = (-0.002029, -0.002010) | Cont-2 = (-0.003677, 0.000537)
# (Velocity, slope): Cont-1 = (-0.002539, -0.001992) | Cont-2 = (-0.003510, 0.000573)
# (Velocity, slope): Cont-1 = (-0.003115, -0.001954) | Cont-2 = (-0.003527, 0.000579)
# (Velocity, slope): Cont-1 = (-0.003133, -0.001886) | Cont-2 = (-0.003866, 0.000585)
# (Velocity, slope): Cont-1 = (-0.003253, -0.001794) | Cont-2 = (-0.003613, 0.000550)
# (Velocity, slope): Cont-1 = (-0.003440, -0.001708) | Cont-2 = (-0.003308, 0.000521)
# (Velocity, slope): Cont-1 = (-0.003651, -0.001622) | Cont-2 = (-0.003009, 0.000497)
# (Velocity, slope): Cont-1 = (-0.003996, -0.001540) | Cont-2 = (-0.002669, 0.000482)
# (Velocity, slope): Cont-1 = (-0.004088, -0.001501) | Cont-2 = (-0.002353, 0.000443)
# (Velocity, slope): Cont-1 = (-0.004110, -0.001443) | Cont-2 = (-0.002066, 0.000409)
# (Velocity, slope): Cont-1 = (-0.004257, -0.001396) | Cont-2 = (-0.001806, 0.000384)
# (Velocity, slope): Cont-1 = (-0.004480, -0.001347) | Cont-2 = (-0.001513, 0.000359)
# (Velocity, slope): Cont-1 = (-0.004606, -0.001292) | Cont-2 = (-0.001214, 0.000337)
# (Velocity, slope): Cont-1 = (-0.004711, -0.001223) | Cont-2 = (-0.000996, 0.000309)
# (Velocity, slope): Cont-1 = (-0.004701, -0.001200) | Cont-2 = (-0.000768, 0.000281)
# (Velocity, slope): Cont-1 = (-0.004722, -0.001176) | Cont-2 = (-0.000560, 0.000254)
# (Velocity, slope): Cont-1 = (-0.004752, -0.001156) | Cont-2 = (-0.000314, 0.000218)
# (Velocity, slope): Cont-1 = (-0.004596, -0.001092) | Cont-2 = (-0.000091, 0.000223)
# (Velocity, slope): Cont-1 = (-0.004561, -0.001032) | Cont-2 = (0.000071, 0.000229)
# (Velocity, slope): Cont-1 = (-0.004538, -0.000967) | Cont-2 = (0.000262, 0.000232)
# (Velocity, slope): Cont-1 = (-0.004377, -0.000913) | Cont-2 = (0.000320, 0.000213)
# (Velocity, slope): Cont-1 = (-0.004199, -0.000863) | Cont-2 = (0.000337, 0.000191)
# (Velocity, slope): Cont-1 = (-0.004080, -0.000812) | Cont-2 = (0.000352, 0.000164)
# (Velocity, slope): Cont-1 = (-0.004043, -0.000764) | Cont-2 = (0.000387, 0.000137)
# (Velocity, slope): Cont-1 = (-0.004025, -0.000708) | Cont-2 = (0.000435, 0.000116)
# (Velocity, slope): Cont-1 = (-0.004027, -0.000672) | Cont-2 = (0.000606, 0.000109)
# (Velocity, slope): Cont-1 = (-0.004071, -0.000636) | Cont-2 = (0.000806, 0.000101)
# (Velocity, slope): Cont-1 = (-0.004088, -0.000607) | Cont-2 = (0.000960, 0.000094)
# (Velocity, slope): Cont-1 = (-0.004019, -0.000578) | Cont-2 = (0.001073, 0.000085)
# (Velocity, slope): Cont-1 = (-0.003878, -0.000544) | Cont-2 = (0.001188, 0.000076)
# (Velocity, slope): Cont-1 = (-0.003774, -0.000512) | Cont-2 = (0.001326, 0.000066)
# (Velocity, slope): Cont-1 = (-0.003678, -0.000480) | Cont-2 = (0.001446, 0.000051)
# (Velocity, slope): Cont-1 = (-0.003570, -0.000444) | Cont-2 = (0.001546, 0.000034)
# (Velocity, slope): Cont-1 = (-0.003491, -0.000408) | Cont-2 = (0.001598, 0.000017)
# (Velocity, slope): Cont-1 = (-0.003486, -0.000459) | Cont-2 = (0.001673, 0.000034)
# (Velocity, slope): Cont-1 = (-0.003459, -0.000502) | Cont-2 = (0.001738, 0.000050)
# (Velocity, slope): Cont-1 = (-0.003429, -0.000550) | Cont-2 = (0.001816, 0.000073)
# (Velocity, slope): Cont-1 = (-0.003377, -0.000615) | Cont-2 = (0.001896, 0.000087)
# (Velocity, slope): Cont-1 = (-0.003319, -0.000680) | Cont-2 = (0.001989, 0.000109)
# (Velocity, slope): Cont-1 = (-0.003253, -0.000747) | Cont-2 = (0.002101, 0.000110)
# (Velocity, slope): Cont-1 = (-0.003169, -0.000824) | Cont-2 = (0.002250, 0.000106)
# (Velocity, slope): Cont-1 = (-0.003088, -0.000897) | Cont-2 = (0.002379, 0.000108)
# (Velocity, slope): Cont-1 = (-0.002992, -0.000992) | Cont-2 = (0.002534, 0.000096)
# (Velocity, slope): Cont-1 = (-0.002896, -0.001079) | Cont-2 = (0.002680, 0.000100)
# (Velocity, slope): Cont-1 = (-0.002791, -0.001187) | Cont-2 = (0.002840, 0.000093)
# (Velocity, slope): Cont-1 = (-0.002698, -0.001284) | Cont-2 = (0.003004, 0.000097)
# (Velocity, slope): Cont-1 = (-0.002564, -0.001325) | Cont-2 = (0.003098, 0.000054)
# (Velocity, slope): Cont-1 = (-0.002598, -0.001317) | Cont-2 = (0.003035, 0.000053)
# (Velocity, slope): Cont-1 = (-0.002565, -0.001328) | Cont-2 = (0.002815, 0.000182)
# (Velocity, slope): Cont-1 = (-0.002591, -0.001294) | Cont-2 = (0.002945, 0.000206)
# (Velocity, slope): Cont-1 = (-0.002643, -0.001283) | Cont-2 = (0.003021, 0.000198)
# (Velocity, slope): Cont-1 = (-0.002704, -0.001273) | Cont-2 = (0.003087, 0.000188)
# (Velocity, slope): Cont-1 = (-0.002765, -0.001261) | Cont-2 = (0.003173, 0.000176)
# (Velocity, slope): Cont-1 = (-0.002824, -0.001252) | Cont-2 = (0.003253, 0.000167)
# (Velocity, slope): Cont-1 = (-0.002861, -0.001239) | Cont-2 = (0.003339, 0.000152)
# (Velocity, slope): Cont-1 = (-0.002897, -0.001225) | Cont-2 = (0.003412, 0.000138)
# (Velocity, slope): Cont-1 = (-0.002936, -0.001210) | Cont-2 = (0.003475, 0.000122)
# (Velocity, slope): Cont-1 = (-0.002981, -0.001193) | Cont-2 = (0.003501, 0.000102)
# (Velocity, slope): Cont-1 = (-0.003038, -0.001179) | Cont-2 = (0.003565, 0.000088)
# (Velocity, slope): Cont-1 = (-0.003070, -0.001161) | Cont-2 = (0.003632, 0.000069)
# (Velocity, slope): Cont-1 = (-0.003099, -0.001144) | Cont-2 = (0.003666, 0.000049)
# (Velocity, slope): Cont-1 = (-0.003125, -0.001127) | Cont-2 = (0.003720, 0.000032)
# (Velocity, slope): Cont-1 = (-0.003121, -0.001112) | Cont-2 = (0.003767, 0.000013)
# (Velocity, slope): Cont-1 = (-0.003207, -0.001092) | Cont-2 = (0.003816, 0.000012)
# (Velocity, slope): Cont-1 = (-0.003285, -0.001046) | Cont-2 = (0.003841, 0.000009)
# (Velocity, slope): Cont-1 = (-0.003287, -0.001027) | Cont-2 = (0.003825, 0.000001)
# (Velocity, slope): Cont-1 = (-0.003403, -0.001011) | Cont-2 = (0.003820, -0.000012)
# (Velocity, slope): Cont-1 = (-0.003587, -0.000998) | Cont-2 = (0.003858, -0.000022)
# (Velocity, slope): Cont-1 = (-0.003796, -0.000992) | Cont-2 = (0.003875, -0.000036)
# (Velocity, slope): Cont-1 = (-0.003984, -0.000984) | Cont-2 = (0.003945, -0.000043)
# (Velocity, slope): Cont-1 = (-0.004167, -0.000974) | Cont-2 = (0.004039, -0.000048)
# (Velocity, slope): Cont-1 = (-0.004347, -0.000964) | Cont-2 = (0.004127, -0.000055)
# (Velocity, slope): Cont-1 = (-0.004534, -0.000952) | Cont-2 = (0.004216, -0.000062)
# (Velocity, slope): Cont-1 = (-0.004707, -0.000943) | Cont-2 = (0.004317, -0.000070)
# (Velocity, slope): Cont-1 = (-0.004631, -0.000993) | Cont-2 = (0.004374, -0.000063)
# (Velocity, slope): Cont-1 = (-0.004537, -0.001049) | Cont-2 = (0.004457, -0.000071)
# (Velocity, slope): Cont-1 = (-0.004441, -0.001104) | Cont-2 = (0.004546, -0.000101)
# (Velocity, slope): Cont-1 = (-0.004354, -0.001145) | Cont-2 = (0.004619, -0.000158)
# (Velocity, slope): Cont-1 = (-0.004361, -0.001177) | Cont-2 = (0.004671, -0.000134)
# (Velocity, slope): Cont-1 = (-0.004376, -0.001203) | Cont-2 = (0.004727, -0.000103)
# (Velocity, slope): Cont-1 = (-0.004387, -0.001258) | Cont-2 = (0.004779, -0.000072)
# (Velocity, slope): Cont-1 = (-0.004394, -0.001301) | Cont-2 = (0.004835, -0.000025)
# (Velocity, slope): Cont-1 = (-0.004341, -0.001336) | Cont-2 = (0.004844, -0.000031)
# (Velocity, slope): Cont-1 = (-0.004282, -0.001366) | Cont-2 = (0.004856, -0.000037)
# (Velocity, slope): Cont-1 = (-0.004349, -0.000757) | Cont-2 = (0.004930, -0.000639)
# (Velocity, slope): Cont-1 = (-0.004443, -0.025567) | Cont-2 = (0.004990, -0.004660)
# (Velocity, slope): Cont-1 = (-0.004371, -0.025403) | Cont-2 = (0.005045, -0.004640)
# (Velocity, slope): Cont-1 = (-0.004308, -0.025238) | Cont-2 = (0.005102, -0.004625)
# (Velocity, slope): Cont-1 = (-0.004286, -0.024970) | Cont-2 = (0.005108, -0.004637)
# (Velocity, slope): Cont-1 = (-0.004251, -0.024727) | Cont-2 = (0.005129, -0.004621)
# (Velocity, slope): Cont-1 = (-0.004220, -0.024499) | Cont-2 = (0.005179, -0.004598)
# (Velocity, slope): Cont-1 = (-0.004211, -0.024277) | Cont-2 = (0.005236, -0.004573)
# (Velocity, slope): Cont-1 = (-0.004245, -0.024107) | Cont-2 = (0.005294, -0.004577)
# (Velocity, slope): Cont-1 = (-0.004370, -0.023905) | Cont-2 = (0.005340, -0.004573)
# (Velocity, slope): Cont-1 = (-0.004338, -0.023732) | Cont-2 = (0.005329, -0.004517)
# (Velocity, slope): Cont-1 = (-0.004232, -0.023569) | Cont-2 = (0.005269, -0.004461)
# (Velocity, slope): Cont-1 = (-0.004114, -0.023409) | Cont-2 = (0.005226, -0.004407)
# (Velocity, slope): Cont-1 = (-0.004000, -0.023270) | Cont-2 = (0.005127, -0.004341)
# (Velocity, slope): Cont-1 = (-0.003871, -0.023128) | Cont-2 = (0.005090, -0.004283)
# (Velocity, slope): Cont-1 = (-0.003735, -0.022986) | Cont-2 = (0.005087, -0.004233)
# (Velocity, slope): Cont-1 = (-0.003798, -0.022806) | Cont-2 = (0.005049, -0.004208)
# (Velocity, slope): Cont-1 = (-0.003864, -0.022629) | Cont-2 = (0.005048, -0.004183)
# (Velocity, slope): Cont-1 = (-0.003906, -0.022456) | Cont-2 = (0.005066, -0.004156)
# (Velocity, slope): Cont-1 = (-0.003978, -0.022286) | Cont-2 = (0.005084, -0.004130)
# (Velocity, slope): Cont-1 = (-0.003990, -0.022117) | Cont-2 = (0.005148, -0.004103)
# (Velocity, slope): Cont-1 = (-0.003984, -0.021951) | Cont-2 = (0.005217, -0.004076)
# (Velocity, slope): Cont-1 = (-0.003896, -0.021778) | Cont-2 = (0.005240, -0.004050)
# (Velocity, slope): Cont-1 = (-0.003849, -0.021610) | Cont-2 = (0.005238, -0.004026)
# (Velocity, slope): Cont-1 = (-0.003819, -0.021444) | Cont-2 = (0.005261, -0.004005)
# (Velocity, slope): Cont-1 = (-0.003868, -0.021294) | Cont-2 = (0.005248, -0.003986)
# (Velocity, slope): Cont-1 = (-0.003912, -0.021145) | Cont-2 = (0.005235, -0.003970)
# (Velocity, slope): Cont-1 = (-0.003974, -0.020987) | Cont-2 = (0.005253, -0.003945)
# (Velocity, slope): Cont-1 = (-0.004011, -0.020829) | Cont-2 = (0.005268, -0.003920)
# (Velocity, slope): Cont-1 = (-0.004065, -0.020669) | Cont-2 = (0.005286, -0.003899)
# (Velocity, slope): Cont-1 = (-0.004124, -0.020511) | Cont-2 = (0.005303, -0.003881)
# (Velocity, slope): Cont-1 = (-0.004146, -0.020373) | Cont-2 = (0.005333, -0.003861)
# (Velocity, slope): Cont-1 = (-0.004166, -0.020237) | Cont-2 = (0.005371, -0.003841)
# (Velocity, slope): Cont-1 = (-0.004090, -0.020090) | Cont-2 = (0.005419, -0.003812)
# (Velocity, slope): Cont-1 = (-0.004021, -0.019942) | Cont-2 = (0.005463, -0.003783)
# (Velocity, slope): Cont-1 = (-0.004004, -0.019798) | Cont-2 = (0.005495, -0.003754)
# (Velocity, slope): Cont-1 = (-0.003974, -0.019656) | Cont-2 = (0.005492, -0.003730)
# (Velocity, slope): Cont-1 = (-0.004007, -0.019515) | Cont-2 = (0.005500, -0.003705)
# (Velocity, slope): Cont-1 = (-0.004008, -0.019376) | Cont-2 = (0.005504, -0.003687)
# (Velocity, slope): Cont-1 = (-0.004028, -0.019241) | Cont-2 = (0.005485, -0.003670)
# (Velocity, slope): Cont-1 = (-0.004004, -0.019112) | Cont-2 = (0.005479, -0.003647)
# (Velocity, slope): Cont-1 = (-0.003961, -0.018983) | Cont-2 = (0.005473, -0.003625)
# (Velocity, slope): Cont-1 = (-0.003920, -0.018856) | Cont-2 = (0.005483, -0.003602)
# (Velocity, slope): Cont-1 = (-0.003886, -0.018730) | Cont-2 = (0.005481, -0.003581)
# (Velocity, slope): Cont-1 = (-0.003836, -0.018605) | Cont-2 = (0.005485, -0.003559)
# (Velocity, slope): Cont-1 = (-0.003794, -0.018481) | Cont-2 = (0.005507, -0.003538)
# (Velocity, slope): Cont-1 = (-0.003739, -0.018359) | Cont-2 = (0.005528, -0.003517)
# (Velocity, slope): Cont-1 = (-0.003692, -0.018238) | Cont-2 = (0.005544, -0.003498)
# (Velocity, slope): Cont-1 = (-0.003623, -0.018118) | Cont-2 = (0.005563, -0.003477)
# (Velocity, slope): Cont-1 = (-0.003557, -0.018000) | Cont-2 = (0.005576, -0.003458)
# (Velocity, slope): Cont-1 = (-0.003476, -0.017883) | Cont-2 = (0.005590, -0.003439)
# (Velocity, slope): Cont-1 = (-0.003392, -0.017767) | Cont-2 = (0.005606, -0.003421)
# (Velocity, slope): Cont-1 = (-0.003308, -0.017652) | Cont-2 = (0.005614, -0.003403)
# (Velocity, slope): Cont-1 = (-0.003225, -0.017539) | Cont-2 = (0.005627, -0.003386)
# (Velocity, slope): Cont-1 = (-0.003137, -0.017426) | Cont-2 = (0.005624, -0.003370)
# (Velocity, slope): Cont-1 = (-0.003098, -0.017315) | Cont-2 = (0.005600, -0.003352)
# (Velocity, slope): Cont-1 = (-0.003116, -0.017208) | Cont-2 = (0.005596, -0.003331)
# (Velocity, slope): Cont-1 = (-0.003113, -0.017099) | Cont-2 = (0.005586, -0.003311)
# (Velocity, slope): Cont-1 = (-0.003159, -0.016994) | Cont-2 = (0.005584, -0.003295)
# (Velocity, slope): Cont-1 = (-0.003236, -0.016895) | Cont-2 = (0.005601, -0.003275)
# (Velocity, slope): Cont-1 = (-0.003292, -0.016792) | Cont-2 = (0.005616, -0.003254)
# (Velocity, slope): Cont-1 = (-0.003333, -0.016687) | Cont-2 = (0.005629, -0.003233)
# (Velocity, slope): Cont-1 = (-0.003395, -0.016584) | Cont-2 = (0.005651, -0.003214)
# (Velocity, slope): Cont-1 = (-0.003463, -0.016482) | Cont-2 = (0.005677, -0.003195)
# (Velocity, slope): Cont-1 = (-0.003529, -0.016383) | Cont-2 = (0.005704, -0.003177)
# (Velocity, slope): Cont-1 = (-0.003602, -0.016283) | Cont-2 = (0.005731, -0.003158)
# (Velocity, slope): Cont-1 = (-0.003670, -0.016185) | Cont-2 = (0.005775, -0.003138)
# Total-Elapsed-Time 0 hour: 8 min: 23 sec
# Eval Time: 0 hour: 8 min: 22 sec
# ===== END -->> 'Data and Time: 15-03-24, 10:57:53 ( 0:08:11.170965 ) =====

# %%
# !cd ../. && python ./trainer_main.py \
--dataset eth \
--epochs 1200 \
--batch-size 64 \
--latent-dim 10 \
--d-learning-rate 1E-3 \
--g-learning-rate 1E-4 \
--unrolling-steps 1 \
--hidden-size 64 \
--n-social-features 3 \
--n-graph-attention-heads 4 \
--model socialWays \
--n-lstm-layers 1 \
--scale-data True \
--social-attention True \
--graph True \
--new-criterion True \
--info-loss-weight 0.9 \
--n-disc-code 2 \
--n-cont-code 2 \
--model-name-append full-10-12 \
--code-eval True \
# --seed 4321
# Out:
# Using torch 2.0.1
# Is the GPU available? False
# Device cpu
# ===== START -->> Data and Time: 23-03-24, 03:09:13 ( Darwin - posix ) =====
# ----- printing args -----
# {   'batch_size': 64,
#     'c1h': False,
#     'code_eval': True,
#     'd_learning_rate': 0.001,
#     'dataset': 'eth',
#     'dataset_parser': 'socialWays',
#     'dataset_type': 'socialWays',
#     'epochs': 1200,
#     'g_learning_rate': 0.0001,
#     'graph': True,
#     'hidden_size': 64,
#     'info_loss_weight': 0.9,
#     'l1o': False,
#     'lambda_cont_code': 0.1,
#     'lambda_disc_code': 0.1,
#     'latent_dim': 10,
#     'lstm_decoder': False,
#     'model': 'socialWays',
#     'model_name_append': 'full-10-12',
#     'n_cont_code': 2,
#     'n_disc_code': 2,
#     'n_graph_attention_heads': 4,
#     'n_lstm_layers': 1,
#     'n_social_features': 3,
#     'new_criterion': True,
#     'nll': False,
#     'scale_data': True,
#     'seed': 1234,
#     'social_attention': True,
#     'unrolling_steps': 1}
# --x-- printing args --x--
# Model File For Training:  ./TRAJ/trained_models/socialWays/eth_sg_22_34_1200-bce-0.9_full-10-12_nec.pt
# Loading model from ./TRAJ/trained_models/socialWays/eth_sg_22_34_1200-bce-0.9_full-10-12_nec.pt
# model trained on: 10-12-23, 08:21:29
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/eth-8-12.npz  # Training samples:  1833
# ./TRAJ/processed/socialWays/eth-8-12.npz  # Test samples:  781
# Batched Test Dataset Creation time: 0 hour: 0 min: 1 sec
# Total Data Processing Time: 0 hour: 0 min: 1 sec
# Performing Code Evaluation on data...
# Categ-1 (angle) = ( -4.697644455462921 | -0.08408490926048663 | 0.0011616632661410956 ) | Categ-2 (dir) =  33.50916420017643 | 46.1616947319363 | 102.82986399237596
# cont-1 (speed) = ( -0.11761106931580564 | -0.06264576624221821 | 0.09926927865793307 ) | cont-2 (shift) =  0.00028473767451941967 | 0.0004307608628716616 | 0.0006941944346181117
# Total-Elapsed-Time 0 hour: 0 min: 43 sec
# Eval Time: 0 hour: 0 min: 43 sec
# ===== END -->> 'Data and Time: 23-03-24, 03:09:55 ( 0:00:41.518552 ) =====
