# %%
# !cd ../. && python ./trainer_main.py \
--dataset univ \
--epochs 800 \
--batch-size 64 \
--latent-dim 10 \
--d-learning-rate 1E-3 \
--g-learning-rate 1E-4 \
--unrolling-steps 1 \
--hidden-size 64 \
--n-social-features 3 \
--n-graph-attention-heads 4 \
--model socialWays \
--n-lstm-layers 1 \
--scale-data True \
--social-attention True \
--graph True \
--new-criterion True \
--info-loss-weight 0.9 \
--n-disc-code 2 \
--n-cont-code 2 \
--model-name-append full-07-12 \
--code-eval True \
# --seed 1234
# Out:
# Using torch 2.0.1
# Is the GPU available? False
# Device cpu
# ===== START -->> Data and Time: 23-03-24, 00:42:21 ( Darwin - posix ) =====
# ----- printing args -----
# {   'batch_size': 64,
#     'c1h': False,
#     'code_eval': True,
#     'd_learning_rate': 0.001,
#     'dataset': 'univ',
#     'dataset_parser': 'socialWays',
#     'dataset_type': 'socialWays',
#     'epochs': 800,
#     'g_learning_rate': 0.0001,
#     'graph': True,
#     'hidden_size': 64,
#     'info_loss_weight': 0.9,
#     'l1o': False,
#     'lambda_cont_code': 0.1,
#     'lambda_disc_code': 0.1,
#     'latent_dim': 10,
#     'lstm_decoder': False,
#     'model': 'socialWays',
#     'model_name_append': 'full-07-12',
#     'n_cont_code': 2,
#     'n_disc_code': 2,
#     'n_graph_attention_heads': 4,
#     'n_lstm_layers': 1,
#     'n_social_features': 3,
#     'new_criterion': True,
#     'nll': False,
#     'scale_data': True,
#     'seed': 1234,
#     'social_attention': True,
#     'unrolling_steps': 1}
# --x-- printing args --x--
# Model File For Training:  ./TRAJ/trained_models/socialWays/univ_sg_22_34_800-bce-0.9_full-07-12_nec.pt
# Loading model from ./TRAJ/trained_models/socialWays/univ_sg_22_34_800-bce-0.9_full-07-12_nec.pt
# model trained on: 08-12-23, 18:31:15
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-0.npz  # Training samples:  11835
# ./TRAJ/processed/socialWays/univ-8-12-0.npz  # Test samples:  2460
# Batched Test Dataset Creation time: 0 hour: 0 min: 10 sec
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-1.npz  # Training samples:  9039
# ./TRAJ/processed/socialWays/univ-8-12-1.npz  # Test samples:  1000
# Batched Test Dataset Creation time: 0 hour: 0 min: 2 sec
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-2.npz  # Training samples:  508
# ./TRAJ/processed/socialWays/univ-8-12-2.npz  # Test samples:  113
# Batched Test Dataset Creation time: 0 hour: 0 min: 1 sec
# Total Data Processing Time: 0 hour: 0 min: 11 sec
# Performing Code Evaluation on data...
# (Velocity, slope, shift): Cont-1 (speed) = (0.057911, -0.058371, 0.001629) | Cont-2 (shift) = (-0.023865, 0.177219, -0.004209)
# Categ-1 (angle) =  105.30326673613435 |Categ-2 (angle) =  153.35853796261978
# (Velocity, slope, shift): Cont-1 (speed) = (0.055305, -0.045186, 0.001381) | Cont-2 (shift) = (-0.029401, 0.650843, -0.004244)
# Categ-1 (angle) =  111.643683531333 |Categ-2 (angle) =  154.38455531936074
# (Velocity, slope, shift): Cont-1 (speed) = (0.033318, -0.123327, 0.001144) | Cont-2 (shift) = (-0.037663, 0.430247, -0.003202)
# Categ-1 (angle) =  85.60468015092658 |Categ-2 (angle) =  119.04089451567269
# (Velocity, slope, shift): Cont-1 (speed) = (0.029889, -0.107103, 0.001068) | Cont-2 (shift) = (-0.039708, 0.375452, -0.002855)
# Categ-1 (angle) =  77.30739366795177 |Categ-2 (angle) =  125.67874555865788
# (Velocity, slope, shift): Cont-1 (speed) = (0.024748, -0.102718, 0.000941) | Cont-2 (shift) = (-0.041019, 0.328521, -0.002541)
# Categ-1 (angle) =  70.3614327915073 |Categ-2 (angle) =  129.46383149100384
# (Velocity, slope, shift): Cont-1 (speed) = (0.022214, -0.096399, 0.000914) | Cont-2 (shift) = (-0.042765, 0.311035, -0.002459)
# Categ-1 (angle) =  66.16349607477991 |Categ-2 (angle) =  133.28820467145573
# (Velocity, slope, shift): Cont-1 (speed) = (0.020540, -0.092520, 0.000894) | Cont-2 (shift) = (-0.044165, 0.287972, -0.002392)
# Categ-1 (angle) =  63.26247567765455 |Categ-2 (angle) =  135.7048485432113
# (Velocity, slope, shift): Cont-1 (speed) = (0.017952, -0.091560, 0.000786) | Cont-2 (shift) = (-0.043357, 0.264886, -0.002221)
# Categ-1 (angle) =  60.11799318756408 |Categ-2 (angle) =  137.54266120356496
# (Velocity, slope, shift): Cont-1 (speed) = (0.012820, -0.079705, 0.000621) | Cont-2 (shift) = (-0.044702, 0.328065, -0.002012)
# Categ-1 (angle) =  59.03098224153489 |Categ-2 (angle) =  127.01650640949659
# (Velocity, slope, shift): Cont-1 (speed) = (0.008569, -0.070144, 0.000507) | Cont-2 (shift) = (-0.046363, 0.496332, -0.001860)
# Categ-1 (angle) =  58.74039867348587 |Categ-2 (angle) =  120.25826645220074
# (Velocity, slope, shift): Cont-1 (speed) = (0.005223, -0.062661, 0.000391) | Cont-2 (shift) = (-0.047424, 0.831384, -0.001738)
# Categ-1 (angle) =  59.18098685608671 |Categ-2 (angle) =  115.5880836260695
# (Velocity, slope, shift): Cont-1 (speed) = (0.002470, -0.057429, 0.000356) | Cont-2 (shift) = (-0.047073, 0.810123, -0.001613)
# Categ-1 (angle) =  58.82652735891973 |Categ-2 (angle) =  111.23208267156969
# (Velocity, slope, shift): Cont-1 (speed) = (0.000422, -0.053068, 0.000326) | Cont-2 (shift) = (-0.046601, 0.782934, -0.001537)
# Categ-1 (angle) =  58.581781190390664 |Categ-2 (angle) =  107.62096848757311
# (Velocity, slope, shift): Cont-1 (speed) = (-0.001354, -0.048817, 0.000300) | Cont-2 (shift) = (-0.046238, 0.746765, -0.001463)
# Categ-1 (angle) =  58.91576378042595 |Categ-2 (angle) =  104.97930403361147
# (Velocity, slope, shift): Cont-1 (speed) = (-0.002754, -0.045049, 0.000261) | Cont-2 (shift) = (-0.046220, 0.714970, -0.001391)
# Categ-1 (angle) =  59.531095522752395 |Categ-2 (angle) =  102.97800396528437
# (Velocity, slope, shift): Cont-1 (speed) = (-0.004053, -0.042944, 0.000301) | Cont-2 (shift) = (-0.043908, 0.619741, -0.001382)
# Categ-1 (angle) =  57.83666219345563 |Categ-2 (angle) =  99.05319968327663
# (Velocity, slope, shift): Cont-1 (speed) = (-0.005485, -0.040571, 0.000334) | Cont-2 (shift) = (-0.041327, 0.569981, -0.001366)
# Categ-1 (angle) =  56.17625686660387 |Categ-2 (angle) =  95.43313112127817
# (Velocity, slope, shift): Cont-1 (speed) = (-0.006685, -0.038587, 0.000346) | Cont-2 (shift) = (-0.039062, 0.525369, -0.001355)
# Categ-1 (angle) =  54.73603634802581 |Categ-2 (angle) =  92.32758753964595
# (Velocity, slope, shift): Cont-1 (speed) = (-0.007518, -0.164312, 0.000354) | Cont-2 (shift) = (-0.037709, 0.491941, -0.001360)
# Categ-1 (angle) =  53.393323610038856 |Categ-2 (angle) =  89.60068232484254
# (Velocity, slope, shift): Cont-1 (speed) = (-0.008150, -0.133382, 0.000354) | Cont-2 (shift) = (-0.036420, 0.462441, -0.001356)
# Categ-1 (angle) =  52.242358187716256 |Categ-2 (angle) =  87.24545551410372
# (Velocity, slope, shift): Cont-1 (speed) = (-0.008794, -0.133237, 0.000346) | Cont-2 (shift) = (-0.035355, 0.432801, -0.001336)
# Categ-1 (angle) =  51.331566122273394 |Categ-2 (angle) =  85.37717337986263
# (Velocity, slope, shift): Cont-1 (speed) = (-0.009234, -0.078244, 0.000329) | Cont-2 (shift) = (-0.034758, 0.407849, -0.001309)
# Categ-1 (angle) =  50.36031663739217 |Categ-2 (angle) =  83.62979925430909
# (Velocity, slope, shift): Cont-1 (speed) = (-0.004600, -0.075585, 0.000518) | Cont-2 (shift) = (-0.037939, 0.386676, -0.001394)
# Categ-1 (angle) =  51.74720703893077 |Categ-2 (angle) =  83.46109358180978
# (Velocity, slope, shift): Cont-1 (speed) = (0.000060, -0.073195, 0.000701) | Cont-2 (shift) = (-0.041166, 0.366959, -0.001513)
# Categ-1 (angle) =  53.1691875373303 |Categ-2 (angle) =  83.5175997368133
# (Velocity, slope, shift): Cont-1 (speed) = (0.003994, -0.070940, 0.000856) | Cont-2 (shift) = (-0.043952, 0.349499, -0.001643)
# Categ-1 (angle) =  54.75827202886879 |Categ-2 (angle) =  83.75651975398034
# (Velocity, slope, shift): Cont-1 (speed) = (0.007717, -0.068800, 0.001013) | Cont-2 (shift) = (-0.046597, 0.333443, -0.001763)
# Categ-1 (angle) =  56.42703409217006 |Categ-2 (angle) =  84.12537045972854
# (Velocity, slope, shift): Cont-1 (speed) = (0.010878, -0.066800, 0.001161) | Cont-2 (shift) = (-0.048945, 0.318848, -0.001882)
# Categ-1 (angle) =  58.08216651298257 |Categ-2 (angle) =  84.63826302488313
# (Velocity, slope, shift): Cont-1 (speed) = (0.014067, -0.064997, 0.001298) | Cont-2 (shift) = (-0.051363, 0.305004, -0.001985)
# Categ-1 (angle) =  59.68404394883649 |Categ-2 (angle) =  85.13121143766129
# (Velocity, slope, shift): Cont-1 (speed) = (0.017327, -0.063320, 0.001428) | Cont-2 (shift) = (-0.053482, 0.291784, -0.002056)
# Categ-1 (angle) =  61.537579704659535 |Categ-2 (angle) =  85.8183011474079
# (Velocity, slope, shift): Cont-1 (speed) = (0.020299, -0.062092, 0.001552) | Cont-2 (shift) = (-0.056525, 0.279399, -0.002162)
# Categ-1 (angle) =  62.92832916307919 |Categ-2 (angle) =  86.39368994346812
# (Velocity, slope, shift): Cont-1 (speed) = (0.021769, -0.061928, 0.001617) | Cont-2 (shift) = (-0.060022, 0.265685, -0.002220)
# Categ-1 (angle) =  63.45275108755277 |Categ-2 (angle) =  86.4244667758682
# (Velocity, slope, shift): Cont-1 (speed) = (0.023354, -0.061336, 0.001674) | Cont-2 (shift) = (-0.063053, 0.254086, -0.002289)
# Categ-1 (angle) =  64.96835640400026 |Categ-2 (angle) =  87.46886417166567
# (Velocity, slope, shift): Cont-1 (speed) = (0.023441, -0.063366, 0.001708) | Cont-2 (shift) = (-0.065989, 0.246556, -0.002320)
# Categ-1 (angle) =  65.3977840574973 |Categ-2 (angle) =  88.39794748370582
# (Velocity, slope, shift): Cont-1 (speed) = (0.022374, -0.065585, 0.001681) | Cont-2 (shift) = (-0.068710, 0.230020, -0.002270)
# Categ-1 (angle) =  66.06195165238934 |Categ-2 (angle) =  89.55382039694709
# (Velocity, slope, shift): Cont-1 (speed) = (0.021699, -0.067602, 0.001669) | Cont-2 (shift) = (-0.071237, 0.241620, -0.002248)
# Categ-1 (angle) =  66.86321480430188 |Categ-2 (angle) =  90.80415482640961
# (Velocity, slope, shift): Cont-1 (speed) = (0.022048, -0.067444, 0.001687) | Cont-2 (shift) = (-0.073040, 0.232355, -0.002253)
# Categ-1 (angle) =  67.35942121731414 |Categ-2 (angle) =  92.31601036900277
# (Velocity, slope, shift): Cont-1 (speed) = (0.023361, -0.066196, 0.001710) | Cont-2 (shift) = (-0.073921, 0.224190, -0.002292)
# Categ-1 (angle) =  68.18172818205947 |Categ-2 (angle) =  93.39677852213057
# (Velocity, slope, shift): Cont-1 (speed) = (0.024494, -0.065118, 0.001728) | Cont-2 (shift) = (-0.074815, 0.216316, -0.002322)
# Categ-1 (angle) =  68.67707399123631 |Categ-2 (angle) =  94.45167391868236
# (Velocity, slope, shift): Cont-1 (speed) = (0.025701, -0.064068, 0.001751) | Cont-2 (shift) = (-0.075588, 0.208751, -0.002358)
# Categ-1 (angle) =  69.20098365152214 |Categ-2 (angle) =  95.36746568259767
# (Velocity, slope, shift): Cont-1 (speed) = (0.027039, -0.063051, 0.001779) | Cont-2 (shift) = (-0.076354, 0.201390, -0.002390)
# Categ-1 (angle) =  70.06315843045284 |Categ-2 (angle) =  96.24384725500201
# (Velocity, slope, shift): Cont-1 (speed) = (0.028409, -0.062030, 0.001809) | Cont-2 (shift) = (-0.077035, 0.194470, -0.002434)
# Categ-1 (angle) =  70.95293400381958 |Categ-2 (angle) =  96.99208081819856
# (Velocity, slope, shift): Cont-1 (speed) = (0.029756, -0.060969, 0.001846) | Cont-2 (shift) = (-0.077539, 0.188018, -0.002475)
# Categ-1 (angle) =  71.73751100358977 |Categ-2 (angle) =  97.60570501323251
# (Velocity, slope, shift): Cont-1 (speed) = (0.031057, -0.060033, 0.001882) | Cont-2 (shift) = (-0.078032, 0.181553, -0.002510)
# Categ-1 (angle) =  72.28221858989829 |Categ-2 (angle) =  98.17955701672946
# (Velocity, slope, shift): Cont-1 (speed) = (0.032177, -0.059039, 0.001914) | Cont-2 (shift) = (-0.078633, 0.175981, -0.002549)
# Categ-1 (angle) =  73.01295320844127 |Categ-2 (angle) =  98.66012912673156
# (Velocity, slope, shift): Cont-1 (speed) = (0.033301, -0.058152, 0.001955) | Cont-2 (shift) = (-0.078595, 0.169300, -0.002585)
# Categ-1 (angle) =  72.33078123489707 |Categ-2 (angle) =  98.53878398593712
# (Velocity, slope, shift): Cont-1 (speed) = (0.034416, -0.057263, 0.001992) | Cont-2 (shift) = (-0.078402, 0.162651, -0.002618)
# Categ-1 (angle) =  71.62533197666149 |Categ-2 (angle) =  97.64971875224407
# (Velocity, slope, shift): Cont-1 (speed) = (0.035264, -0.056482, 0.002012) | Cont-2 (shift) = (-0.077967, 0.154039, -0.002644)
# Categ-1 (angle) =  71.03238959443433 |Categ-2 (angle) =  96.57796644882069
# (Velocity, slope, shift): Cont-1 (speed) = (0.036245, -0.055628, 0.002029) | Cont-2 (shift) = (-0.078495, 0.149006, -0.002695)
# Categ-1 (angle) =  70.78834010520062 |Categ-2 (angle) =  95.87356903971727
# (Velocity, slope, shift): Cont-1 (speed) = (0.037174, -0.054766, 0.002044) | Cont-2 (shift) = (-0.079133, 0.144359, -0.002743)
# Categ-1 (angle) =  70.59035341172945 |Categ-2 (angle) =  95.2429581642175
# (Velocity, slope, shift): Cont-1 (speed) = (0.038157, -0.054007, 0.002059) | Cont-2 (shift) = (-0.079732, 0.139495, -0.002796)
# Categ-1 (angle) =  70.43127147577069 |Categ-2 (angle) =  94.67127816087661
# (Velocity, slope, shift): Cont-1 (speed) = (0.038970, -0.053291, 0.002068) | Cont-2 (shift) = (-0.080323, 0.134838, -0.002848)
# Categ-1 (angle) =  70.32718622300887 |Categ-2 (angle) =  94.16709408691378
# (Velocity, slope, shift): Cont-1 (speed) = (0.039743, -0.052640, 0.002077) | Cont-2 (shift) = (-0.080877, 0.130406, -0.002896)
# Categ-1 (angle) =  70.2427650848675 |Categ-2 (angle) =  93.7044648838613
# (Velocity, slope, shift): Cont-1 (speed) = (0.040387, -0.051951, 0.002077) | Cont-2 (shift) = (-0.081429, 0.126409, -0.002941)
# Categ-1 (angle) =  70.16707975867459 |Categ-2 (angle) =  93.2672849656563
# (Velocity, slope, shift): Cont-1 (speed) = (0.040972, -0.051318, 0.002075) | Cont-2 (shift) = (-0.081947, 0.122694, -0.002983)
# Categ-1 (angle) =  70.08901069646134 |Categ-2 (angle) =  92.86955622009728
# (Velocity, slope, shift): Cont-1 (speed) = (0.041578, -0.050718, 0.002077) | Cont-2 (shift) = (-0.082409, 0.118849, -0.003027)
# Categ-1 (angle) =  69.95803498893719 |Categ-2 (angle) =  92.44737539730963
# (Velocity, slope, shift): Cont-1 (speed) = (0.042216, -0.050178, 0.002085) | Cont-2 (shift) = (-0.082810, 0.114944, -0.003061)
# Categ-1 (angle) =  69.69587183802459 |Categ-2 (angle) =  92.02959321634745
# (Velocity, slope, shift): Cont-1 (speed) = (0.042933, -0.049646, 0.002098) | Cont-2 (shift) = (-0.083321, 0.111323, -0.003094)
# Categ-1 (angle) =  69.32786807573346 |Categ-2 (angle) =  91.58020091990646
# (Velocity, slope, shift): Cont-1 (speed) = (0.043536, -0.049129, 0.002113) | Cont-2 (shift) = (-0.083807, 0.107697, -0.003115)
# Categ-1 (angle) =  68.88327740227899 |Categ-2 (angle) =  91.13468817091405
# (Velocity, slope, shift): Cont-1 (speed) = (0.044075, -0.048663, 0.002123) | Cont-2 (shift) = (-0.084399, 0.104245, -0.003138)
# Categ-1 (angle) =  68.47574733526102 |Categ-2 (angle) =  90.7635493517939
# (Velocity, slope, shift): Cont-1 (speed) = (0.044515, -0.048227, 0.002132) | Cont-2 (shift) = (-0.084794, 0.101181, -0.003155)
# Categ-1 (angle) =  68.09111889253009 |Categ-2 (angle) =  90.42848076168058
# (Velocity, slope, shift): Cont-1 (speed) = (0.044878, -0.047990, 0.002138) | Cont-2 (shift) = (-0.085308, 0.097943, -0.003167)
# Categ-1 (angle) =  68.17831991766364 |Categ-2 (angle) =  90.19523663171381
# (Velocity, slope, shift): Cont-1 (speed) = (0.045176, -0.047719, 0.002144) | Cont-2 (shift) = (-0.085759, 0.094880, -0.003182)
# Categ-1 (angle) =  68.3066318514115 |Categ-2 (angle) =  89.96122069037084
# (Velocity, slope, shift): Cont-1 (speed) = (0.045476, -0.047685, 0.002151) | Cont-2 (shift) = (-0.086281, 0.090886, -0.003198)
# Categ-1 (angle) =  68.49315065726621 |Categ-2 (angle) =  89.76785803496777
# (Velocity, slope, shift): Cont-1 (speed) = (0.045872, -0.047464, 0.002158) | Cont-2 (shift) = (-0.086957, 0.087844, -0.003216)
# Categ-1 (angle) =  68.93339733040855 |Categ-2 (angle) =  89.59550504145167
# (Velocity, slope, shift): Cont-1 (speed) = (0.046290, -0.047281, 0.002167) | Cont-2 (shift) = (-0.087664, 0.084754, -0.003239)
# Categ-1 (angle) =  69.35916400251047 |Categ-2 (angle) =  89.43784378484027
# (Velocity, slope, shift): Cont-1 (speed) = (0.046650, -0.047063, 0.002176) | Cont-2 (shift) = (-0.088340, 0.082294, -0.003259)
# Categ-1 (angle) =  70.0430571837255 |Categ-2 (angle) =  89.28783917028845
# (Velocity, slope, shift): Cont-1 (speed) = (0.046949, -0.046754, 0.002178) | Cont-2 (shift) = (-0.088735, 0.079998, -0.003265)
# Categ-1 (angle) =  69.89424785227843 |Categ-2 (angle) =  89.10227659091754
# (Velocity, slope, shift): Cont-1 (speed) = (0.047257, -0.046441, 0.002183) | Cont-2 (shift) = (-0.089291, 0.077741, -0.003279)
# Categ-1 (angle) =  69.94738672402113 |Categ-2 (angle) =  88.94270288133853
# (Velocity, slope, shift): Cont-1 (speed) = (0.047560, -0.046133, 0.002190) | Cont-2 (shift) = (-0.089809, 0.075540, -0.003295)
# Categ-1 (angle) =  69.89401562584665 |Categ-2 (angle) =  88.76428467983946
# (Velocity, slope, shift): Cont-1 (speed) = (0.047916, -0.045831, 0.002199) | Cont-2 (shift) = (-0.090192, 0.073559, -0.003308)
# Categ-1 (angle) =  69.8154001484998 |Categ-2 (angle) =  88.54890149455228
# (Velocity, slope, shift): Cont-1 (speed) = (0.048213, -0.045563, 0.002207) | Cont-2 (shift) = (-0.090574, 0.071510, -0.003319)
# Categ-1 (angle) =  69.64324523046963 |Categ-2 (angle) =  88.33808770581983
# (Velocity, slope, shift): Cont-1 (speed) = (0.048481, -0.045362, 0.002209) | Cont-2 (shift) = (-0.090941, 0.069284, -0.003326)
# Categ-1 (angle) =  69.37301562614725 |Categ-2 (angle) =  88.1460637674941
# (Velocity, slope, shift): Cont-1 (speed) = (0.048711, -0.045143, 0.002210) | Cont-2 (shift) = (-0.091260, 0.067213, -0.003334)
# Categ-1 (angle) =  69.07849103894713 |Categ-2 (angle) =  87.95151265917545
# (Velocity, slope, shift): Cont-1 (speed) = (0.048880, -0.044959, 0.002212) | Cont-2 (shift) = (-0.091552, 0.065134, -0.003342)
# Categ-1 (angle) =  68.77389875291041 |Categ-2 (angle) =  87.76097770208878
# (Velocity, slope, shift): Cont-1 (speed) = (0.049205, -0.044759, 0.002220) | Cont-2 (shift) = (-0.091827, 0.063108, -0.003348)
# Categ-1 (angle) =  68.46326174945823 |Categ-2 (angle) =  87.54122319573278
# (Velocity, slope, shift): Cont-1 (speed) = (0.049470, -0.044538, 0.002226) | Cont-2 (shift) = (-0.092115, 0.061133, -0.003359)
# Categ-1 (angle) =  68.17204980400557 |Categ-2 (angle) =  87.3280734823042
# (Velocity, slope, shift): Cont-1 (speed) = (0.049789, -0.044295, 0.002235) | Cont-2 (shift) = (-0.092349, 0.059115, -0.003371)
# Categ-1 (angle) =  67.87925325466546 |Categ-2 (angle) =  87.0853832007153
# (Velocity, slope, shift): Cont-1 (speed) = (0.050193, -0.044014, 0.002249) | Cont-2 (shift) = (-0.092597, 0.057385, -0.003387)
# Categ-1 (angle) =  67.70830728011838 |Categ-2 (angle) =  86.84409993809544
# (Velocity, slope, shift): Cont-1 (speed) = (0.050532, -0.043805, 0.002259) | Cont-2 (shift) = (-0.092845, 0.055409, -0.003401)
# Categ-1 (angle) =  67.46939409314051 |Categ-2 (angle) =  86.61729667651599
# (Velocity, slope, shift): Cont-1 (speed) = (0.050845, -0.043669, 0.002276) | Cont-2 (shift) = (-0.093005, 0.052673, -0.003423)
# Categ-1 (angle) =  67.26554709736148 |Categ-2 (angle) =  86.37571971576182
# (Velocity, slope, shift): Cont-1 (speed) = (0.051225, -0.043441, 0.002292) | Cont-2 (shift) = (-0.093093, 0.050604, -0.003446)
# Categ-1 (angle) =  67.13756984288294 |Categ-2 (angle) =  86.1160632442746
# (Velocity, slope, shift): Cont-1 (speed) = (0.051541, -0.043319, 0.002307) | Cont-2 (shift) = (-0.093089, 0.047839, -0.003463)
# Categ-1 (angle) =  67.46929164030296 |Categ-2 (angle) =  86.33904159991884
# (Velocity, slope, shift): Cont-1 (speed) = (0.051883, -0.043230, 0.002326) | Cont-2 (shift) = (-0.093178, 0.041828, -0.003484)
# Categ-1 (angle) =  67.99317397983211 |Categ-2 (angle) =  86.74698830847619
# (Velocity, slope, shift): Cont-1 (speed) = (0.052257, -0.043091, 0.002342) | Cont-2 (shift) = (-0.093285, 0.037673, -0.003504)
# Categ-1 (angle) =  68.6137786281978 |Categ-2 (angle) =  87.19683822759157
# (Velocity, slope, shift): Cont-1 (speed) = (0.052884, -0.042869, 0.002380) | Cont-2 (shift) = (-0.093665, 0.036376, -0.003535)
# Categ-1 (angle) =  69.30467958350127 |Categ-2 (angle) =  86.79541434969158
# (Velocity, slope, shift): Cont-1 (speed) = (0.052665, -0.042573, 0.002363) | Cont-2 (shift) = (-0.093973, 0.035507, -0.003518)
# Categ-1 (angle) =  68.8898138933147 |Categ-2 (angle) =  86.21139219452047
# (Velocity, slope, shift): Cont-1 (speed) = (0.052418, -0.042332, 0.002345) | Cont-2 (shift) = (-0.094452, 0.034556, -0.003507)
# Categ-1 (angle) =  68.47744122217517 |Categ-2 (angle) =  85.62990403953144
# (Velocity, slope, shift): Cont-1 (speed) = (0.052335, -0.042113, 0.002328) | Cont-2 (shift) = (-0.095030, 0.033599, -0.003506)
# Categ-1 (angle) =  68.08407013730664 |Categ-2 (angle) =  85.07234203720496
# (Velocity, slope, shift): Cont-1 (speed) = (0.052175, -0.041888, 0.002307) | Cont-2 (shift) = (-0.095477, 0.032697, -0.003500)
# Categ-1 (angle) =  67.70012471349271 |Categ-2 (angle) =  84.53277075315229
# (Velocity, slope, shift): Cont-1 (speed) = (0.052218, -0.041660, 0.002302) | Cont-2 (shift) = (-0.095832, 0.031886, -0.003495)
# Categ-1 (angle) =  67.35117717898592 |Categ-2 (angle) =  84.04373603876854
# (Velocity, slope, shift): Cont-1 (speed) = (0.052133, -0.041450, 0.002294) | Cont-2 (shift) = (-0.096306, 0.030979, -0.003483)
# Categ-1 (angle) =  66.99268787020864 |Categ-2 (angle) =  83.54606113508474
# (Velocity, slope, shift): Cont-1 (speed) = (0.052087, -0.041167, 0.002285) | Cont-2 (shift) = (-0.096566, 0.030115, -0.003476)
# Categ-1 (angle) =  66.62462946640416 |Categ-2 (angle) =  83.04902143899373
# (Velocity, slope, shift): Cont-1 (speed) = (0.052354, -0.040978, 0.002295) | Cont-2 (shift) = (-0.096928, 0.029206, -0.003475)
# Categ-1 (angle) =  66.30451216038401 |Categ-2 (angle) =  82.62494865380599
# (Velocity, slope, shift): Cont-1 (speed) = (0.052447, -0.040812, 0.002302) | Cont-2 (shift) = (-0.097388, 0.028371, -0.003470)
# Categ-1 (angle) =  65.95585832401153 |Categ-2 (angle) =  82.17247594204932
# (Velocity, slope, shift): Cont-1 (speed) = (0.052519, -0.040675, 0.002314) | Cont-2 (shift) = (-0.097811, 0.027549, -0.003464)
# Categ-1 (angle) =  65.62444388510417 |Categ-2 (angle) =  81.75944074256032
# (Velocity, slope, shift): Cont-1 (speed) = (0.052743, -0.040445, 0.002322) | Cont-2 (shift) = (-0.098120, 0.026801, -0.003462)
# Categ-1 (angle) =  65.35964428117195 |Categ-2 (angle) =  81.40468071706985
# (Velocity, slope, shift): Cont-1 (speed) = (0.051415, -0.040005, 0.002326) | Cont-2 (shift) = (-0.097231, 0.024201, -0.003432)
# Categ-1 (angle) =  64.98752874500049 |Categ-2 (angle) =  80.92257864469367
# (Velocity, slope, shift): Cont-1 (speed) = (0.050020, -0.041608, 0.002333) | Cont-2 (shift) = (-0.096473, 0.022971, -0.003407)
# Categ-1 (angle) =  64.6224073225391 |Categ-2 (angle) =  80.45387057327989
# (Velocity, slope, shift): Cont-1 (speed) = (0.049006, -0.034408, 0.002362) | Cont-2 (shift) = (-0.094936, 0.022213, -0.003403)
# Categ-1 (angle) =  64.2582284661832 |Categ-2 (angle) =  79.96799823648186
# (Velocity, slope, shift): Cont-1 (speed) = (0.047977, -0.036085, 0.002391) | Cont-2 (shift) = (-0.093701, 0.021605, -0.003401)
# Categ-1 (angle) =  63.90324304445013 |Categ-2 (angle) =  79.50299895778738
# (Velocity, slope, shift): Cont-1 (speed) = (0.047158, 0.352471, 0.002417) | Cont-2 (shift) = (-0.092308, 0.020965, -0.003398)
# Categ-1 (angle) =  63.55040913230561 |Categ-2 (angle) =  79.03450945242705
# (Velocity, slope, shift): Cont-1 (speed) = (0.046465, 0.347721, 0.002433) | Cont-2 (shift) = (-0.091145, 0.020555, -0.003390)
# Categ-1 (angle) =  63.202909597902874 |Categ-2 (angle) =  78.57571881568812
# (Velocity, slope, shift): Cont-1 (speed) = (0.046253, 0.343830, 0.002460) | Cont-2 (shift) = (-0.090108, 0.020640, -0.003395)
# Categ-1 (angle) =  62.86800493232963 |Categ-2 (angle) =  78.14189935055477
# (Velocity, slope, shift): Cont-1 (speed) = (0.045683, 0.339424, 0.002476) | Cont-2 (shift) = (-0.089014, 0.020304, -0.003396)
# Categ-1 (angle) =  62.53340079507988 |Categ-2 (angle) =  77.71018358368576
# (Velocity, slope, shift): Cont-1 (speed) = (0.044649, 0.338055, 0.002464) | Cont-2 (shift) = (-0.088552, 0.019565, -0.003400)
# Categ-1 (angle) =  62.2699125874683 |Categ-2 (angle) =  77.39797563672448
# (Velocity, slope, shift): Cont-1 (speed) = (0.044048, 0.317088, 0.002455) | Cont-2 (shift) = (-0.087402, 0.019319, -0.003405)
# Categ-1 (angle) =  61.95352456473497 |Categ-2 (angle) =  77.0003971553272
# (Velocity, slope, shift): Cont-1 (speed) = (0.043626, 0.316735, 0.002448) | Cont-2 (shift) = (-0.085959, 0.019214, -0.003409)
# Categ-1 (angle) =  61.634745975792136 |Categ-2 (angle) =  76.58486893679114
# (Velocity, slope, shift): Cont-1 (speed) = (0.042655, 0.313958, 0.002448) | Cont-2 (shift) = (-0.085110, 0.018012, -0.003401)
# Categ-1 (angle) =  61.3270596140614 |Categ-2 (angle) =  76.19398404078048
# (Velocity, slope, shift): Cont-1 (speed) = (0.041809, 0.311218, 0.002438) | Cont-2 (shift) = (-0.084335, 0.016734, -0.003388)
# Categ-1 (angle) =  61.0278836680365 |Categ-2 (angle) =  75.8136039757133
# (Velocity, slope, shift): Cont-1 (speed) = (0.041295, 0.312047, 0.002456) | Cont-2 (shift) = (-0.084563, 0.016310, -0.003415)
# Categ-1 (angle) =  60.86909543021204 |Categ-2 (angle) =  75.86465280956998
# (Velocity, slope, shift): Cont-1 (speed) = (0.041026, 0.315974, 0.002455) | Cont-2 (shift) = (-0.084843, 0.015961, -0.003434)
# Categ-1 (angle) =  60.72710262755665 |Categ-2 (angle) =  75.8140615983877
# (Velocity, slope, shift): Cont-1 (speed) = (0.041167, 0.312077, 0.002444) | Cont-2 (shift) = (-0.085262, 0.016097, -0.003440)
# Categ-1 (angle) =  60.685766322699735 |Categ-2 (angle) =  76.00621531030767
# (Velocity, slope, shift): Cont-1 (speed) = (0.041260, 0.300598, 0.002437) | Cont-2 (shift) = (-0.085233, 0.016241, -0.003458)
# Categ-1 (angle) =  60.4719882318675 |Categ-2 (angle) =  76.05732561586687
# (Velocity, slope, shift): Cont-1 (speed) = (0.041512, 0.297762, 0.002431) | Cont-2 (shift) = (-0.085756, 0.012635, -0.003476)
# Categ-1 (angle) =  61.169651074449284 |Categ-2 (angle) =  76.65540430034986
# (Velocity, slope, shift): Cont-1 (speed) = (0.041723, 0.295021, 0.002417) | Cont-2 (shift) = (-0.086160, 0.010379, -0.003491)
# Categ-1 (angle) =  61.89261976790596 |Categ-2 (angle) =  77.24259566329586
# (Velocity, slope, shift): Cont-1 (speed) = (0.041770, 0.292362, 0.002392) | Cont-2 (shift) = (-0.086453, 0.009213, -0.003498)
# Categ-1 (angle) =  62.612494385668626 |Categ-2 (angle) =  77.82397453525817
# (Velocity, slope, shift): Cont-1 (speed) = (0.041759, 0.289763, 0.002364) | Cont-2 (shift) = (-0.086681, 0.008197, -0.003503)
# Categ-1 (angle) =  63.33012187119436 |Categ-2 (angle) =  78.40193148244632
# (Velocity, slope, shift): Cont-1 (speed) = (0.041670, 0.286808, 0.002356) | Cont-2 (shift) = (-0.086952, 0.009911, -0.003513)
# Categ-1 (angle) =  64.0996314736555 |Categ-2 (angle) =  78.97908929750156
# (Velocity, slope, shift): Cont-1 (speed) = (0.041322, 0.283448, 0.002350) | Cont-2 (shift) = (-0.087193, 0.010184, -0.003515)
# Categ-1 (angle) =  64.22359940709124 |Categ-2 (angle) =  79.53212288440832
# (Velocity, slope, shift): Cont-1 (speed) = (0.041398, 0.280729, 0.002350) | Cont-2 (shift) = (-0.087387, -0.009493, -0.003522)
# Categ-1 (angle) =  64.2583650699666 |Categ-2 (angle) =  80.0556363937223
# (Velocity, slope, shift): Cont-1 (speed) = (0.041481, 0.277946, 0.002356) | Cont-2 (shift) = (-0.087587, -0.007758, -0.003537)
# Categ-1 (angle) =  64.07121105651908 |Categ-2 (angle) =  80.57823465768747
# (Velocity, slope, shift): Cont-1 (speed) = (0.041520, 0.275303, 0.002353) | Cont-2 (shift) = (-0.087671, -0.001181, -0.003543)
# Categ-1 (angle) =  63.8721588535374 |Categ-2 (angle) =  81.05541216367207
# (Velocity, slope, shift): Cont-1 (speed) = (0.041725, 0.272291, 0.002362) | Cont-2 (shift) = (-0.087769, -0.000415, -0.003565)
# Categ-1 (angle) =  64.37494273872038 |Categ-2 (angle) =  81.55304608622087
# (Velocity, slope, shift): Cont-1 (speed) = (0.041636, 0.271909, 0.002368) | Cont-2 (shift) = (-0.087614, -0.000278, -0.003587)
# Categ-1 (angle) =  64.90471953150325 |Categ-2 (angle) =  81.83407421962104
# (Velocity, slope, shift): Cont-1 (speed) = (0.041638, 0.267862, 0.002369) | Cont-2 (shift) = (-0.087618, -0.000012, -0.003608)
# Categ-1 (angle) =  65.5700687491217 |Categ-2 (angle) =  81.9845023059014
# (Velocity, slope, shift): Cont-1 (speed) = (0.041466, 0.263190, 0.002354) | Cont-2 (shift) = (-0.087535, 0.000161, -0.003606)
# Categ-1 (angle) =  65.83085903201113 |Categ-2 (angle) =  82.22169428520844
# (Velocity, slope, shift): Cont-1 (speed) = (0.041464, 0.260803, 0.002339) | Cont-2 (shift) = (-0.087641, 0.007794, -0.003604)
# Categ-1 (angle) =  66.2895472159125 |Categ-2 (angle) =  82.46096947221233
# (Velocity, slope, shift): Cont-1 (speed) = (0.041463, 0.258479, 0.002324) | Cont-2 (shift) = (-0.087936, 0.003018, -0.003604)
# Categ-1 (angle) =  66.65012656257582 |Categ-2 (angle) =  82.62363042729618
# (Velocity, slope, shift): Cont-1 (speed) = (0.041401, 0.256237, 0.002303) | Cont-2 (shift) = (-0.088222, -0.002967, -0.003602)
# Categ-1 (angle) =  67.03823157159428 |Categ-2 (angle) =  82.75959900310362
# (Velocity, slope, shift): Cont-1 (speed) = (0.041392, 0.254125, 0.002281) | Cont-2 (shift) = (-0.088383, -0.003548, -0.003597)
# Categ-1 (angle) =  67.45616401671819 |Categ-2 (angle) =  82.97134169756319
# (Velocity, slope, shift): Cont-1 (speed) = (0.041365, 0.252039, 0.002258) | Cont-2 (shift) = (-0.088671, -0.004207, -0.003594)
# Categ-1 (angle) =  67.82456392998117 |Categ-2 (angle) =  83.13260929405635
# (Velocity, slope, shift): Cont-1 (speed) = (0.041264, 0.250017, 0.002231) | Cont-2 (shift) = (-0.088999, -0.004816, -0.003588)
# Categ-1 (angle) =  68.19305263570335 |Categ-2 (angle) =  83.29650651337998
# (Velocity, slope, shift): Cont-1 (speed) = (0.041166, 0.248060, 0.002202) | Cont-2 (shift) = (-0.089369, -0.005317, -0.003582)
# Categ-1 (angle) =  68.54932896318957 |Categ-2 (angle) =  83.43362939115715
# (Velocity, slope, shift): Cont-1 (speed) = (0.041075, 0.246132, 0.002174) | Cont-2 (shift) = (-0.089808, -0.005801, -0.003579)
# Categ-1 (angle) =  68.86935064656134 |Categ-2 (angle) =  83.5367310966785
# (Velocity, slope, shift): Cont-1 (speed) = (0.041019, 0.244235, 0.002151) | Cont-2 (shift) = (-0.090188, -0.006222, -0.003580)
# Categ-1 (angle) =  69.16926425301659 |Categ-2 (angle) =  83.64201846273424
# (Velocity, slope, shift): Cont-1 (speed) = (0.040701, 0.242010, 0.002143) | Cont-2 (shift) = (-0.090970, -0.006199, -0.003580)
# Categ-1 (angle) =  69.10488288990005 |Categ-2 (angle) =  83.36352432951615
# (Velocity, slope, shift): Cont-1 (speed) = (0.040249, 0.239116, 0.002136) | Cont-2 (shift) = (-0.091719, -0.007790, -0.003580)
# Categ-1 (angle) =  69.0035365429954 |Categ-2 (angle) =  83.04949955223564
# (Velocity, slope, shift): Cont-1 (speed) = (0.039886, 0.236482, 0.002134) | Cont-2 (shift) = (-0.092455, -0.014262, -0.003582)
# Categ-1 (angle) =  68.93635480231916 |Categ-2 (angle) =  82.7668253432455
# (Velocity, slope, shift): Cont-1 (speed) = (0.039637, 0.234081, 0.002128) | Cont-2 (shift) = (-0.093361, -0.015747, -0.003595)
# Categ-1 (angle) =  68.92391702784057 |Categ-2 (angle) =  82.493979776471
# (Velocity, slope, shift): Cont-1 (speed) = (0.039457, 0.231933, 0.002124) | Cont-2 (shift) = (-0.094265, -0.015269, -0.003608)
# Categ-1 (angle) =  68.92698378277791 |Categ-2 (angle) =  82.25922617469766
# (Velocity, slope, shift): Cont-1 (speed) = (0.039101, 0.229610, 0.002108) | Cont-2 (shift) = (-0.094725, -0.011932, -0.003609)
# Categ-1 (angle) =  68.88623487418961 |Categ-2 (angle) =  81.97655196570751
# (Velocity, slope, shift): Cont-1 (speed) = (0.038747, 0.227489, 0.002094) | Cont-2 (shift) = (-0.095140, -0.011232, -0.003609)
# Categ-1 (angle) =  68.85415347565807 |Categ-2 (angle) =  81.72238013612382
# (Velocity, slope, shift): Cont-1 (speed) = (0.038399, 0.225644, 0.002071) | Cont-2 (shift) = (-0.095647, -0.011042, -0.003608)
# Categ-1 (angle) =  68.75588071387992 |Categ-2 (angle) =  81.4799015903992
# (Velocity, slope, shift): Cont-1 (speed) = (0.038023, 0.223847, 0.002048) | Cont-2 (shift) = (-0.096103, -0.010680, -0.003604)
# Categ-1 (angle) =  68.68562538807717 |Categ-2 (angle) =  81.2575994234828
# (Velocity, slope, shift): Cont-1 (speed) = (0.037653, 0.221882, 0.002031) | Cont-2 (shift) = (-0.096664, -0.011429, -0.003605)
# Categ-1 (angle) =  68.63510247878658 |Categ-2 (angle) =  81.03640374721193
# (Velocity, slope, shift): Cont-1 (speed) = (0.037231, 0.220158, 0.002006) | Cont-2 (shift) = (-0.096999, -0.011544, -0.003591)
# Categ-1 (angle) =  68.74719271325566 |Categ-2 (angle) =  80.94519340103558
# (Velocity, slope, shift): Cont-1 (speed) = (0.036784, 0.218035, 0.001986) | Cont-2 (shift) = (-0.097337, -0.012004, -0.003577)
# Categ-1 (angle) =  68.77543554547367 |Categ-2 (angle) =  80.77732784180418
# (Velocity, slope, shift): Cont-1 (speed) = (0.036296, 0.214892, 0.001964) | Cont-2 (shift) = (-0.097459, -0.012821, -0.003562)
# Categ-1 (angle) =  68.74051961843656 |Categ-2 (angle) =  80.56675993988186
# (Velocity, slope, shift): Cont-1 (speed) = (0.035883, 0.214306, 0.001943) | Cont-2 (shift) = (-0.097165, -0.016824, -0.003548)
# Categ-1 (angle) =  68.53290918842485 |Categ-2 (angle) =  80.27482399437717
# (Velocity, slope, shift): Cont-1 (speed) = (0.035479, 0.213698, 0.001921) | Cont-2 (shift) = (-0.096901, -0.020167, -0.003532)
# Categ-1 (angle) =  68.32835868316131 |Categ-2 (angle) =  79.98675393594272
# (Velocity, slope, shift): Cont-1 (speed) = (0.035103, 0.213618, 0.001896) | Cont-2 (shift) = (-0.096649, -0.023073, -0.003514)
# Categ-1 (angle) =  68.16490542613373 |Categ-2 (angle) =  79.72404436989652
# (Velocity, slope, shift): Cont-1 (speed) = (0.034735, 0.213230, 0.001874) | Cont-2 (shift) = (-0.096505, -0.024052, -0.003498)
# Categ-1 (angle) =  67.94036978735873 |Categ-2 (angle) =  79.47210601217142
# (Velocity, slope, shift): Cont-1 (speed) = (0.034358, 0.212337, 0.001851) | Cont-2 (shift) = (-0.096281, -0.041785, -0.003478)
# Categ-1 (angle) =  67.74049113148749 |Categ-2 (angle) =  79.22024961671637
# (Velocity, slope, shift): Cont-1 (speed) = (0.033992, 0.210383, 0.001830) | Cont-2 (shift) = (-0.096466, -0.042092, -0.003467)
# Categ-1 (angle) =  67.57916889348095 |Categ-2 (angle) =  79.06387243566893
# (Velocity, slope, shift): Cont-1 (speed) = (0.033744, 0.208806, 0.001809) | Cont-2 (shift) = (-0.096875, -0.042153, -0.003455)
# Categ-1 (angle) =  67.5955340267323 |Categ-2 (angle) =  79.04592952871931
# (Velocity, slope, shift): Cont-1 (speed) = (0.033471, 0.207220, 0.001788) | Cont-2 (shift) = (-0.097297, -0.042280, -0.003443)
# Categ-1 (angle) =  67.58354021454976 |Categ-2 (angle) =  79.00703843158526
# (Velocity, slope, shift): Cont-1 (speed) = (0.033109, 0.205370, 0.001767) | Cont-2 (shift) = (-0.097550, -0.042447, -0.003429)
# Categ-1 (angle) =  67.45496873361344 |Categ-2 (angle) =  78.8671971385184
# (Velocity, slope, shift): Cont-1 (speed) = (0.032782, 0.201211, 0.001755) | Cont-2 (shift) = (-0.097711, -0.042743, -0.003422)
# Categ-1 (angle) =  67.25711181373651 |Categ-2 (angle) =  78.65119923620593
# (Velocity, slope, shift): Cont-1 (speed) = (0.032489, 0.204530, 0.001732) | Cont-2 (shift) = (-0.097629, -0.043124, -0.003406)
# Categ-1 (angle) =  67.02823217464937 |Categ-2 (angle) =  78.3572688754636
# (Velocity, slope, shift): Cont-1 (speed) = (0.032258, 0.206608, 0.001715) | Cont-2 (shift) = (-0.097808, -0.043604, -0.003398)
# Categ-1 (angle) =  66.8188595558318 |Categ-2 (angle) =  78.12205765101588
# (Velocity, slope, shift): Cont-1 (speed) = (0.032198, 0.204585, 0.001698) | Cont-2 (shift) = (-0.098289, -0.043749, -0.003397)
# Categ-1 (angle) =  66.65646497812558 |Categ-2 (angle) =  77.94148793992825
# (Velocity, slope, shift): Cont-1 (speed) = (0.032067, 0.203036, 0.001680) | Cont-2 (shift) = (-0.098889, -0.043773, -0.003392)
# Categ-1 (angle) =  66.51229334512496 |Categ-2 (angle) =  77.80319026961382
# (Velocity, slope, shift): Cont-1 (speed) = (0.031967, 0.201569, 0.001662) | Cont-2 (shift) = (-0.099403, -0.044052, -0.003385)
# Categ-1 (angle) =  66.33780250239865 |Categ-2 (angle) =  77.62877455896839
# (Velocity, slope, shift): Cont-1 (speed) = (0.031813, 0.200101, 0.001642) | Cont-2 (shift) = (-0.099934, -0.044223, -0.003374)
# Categ-1 (angle) =  66.52500432717035 |Categ-2 (angle) =  77.64829523961627
# (Velocity, slope, shift): Cont-1 (speed) = (0.031642, 0.198655, 0.001623) | Cont-2 (shift) = (-0.100447, -0.044517, -0.003361)
# Categ-1 (angle) =  66.85472487916354 |Categ-2 (angle) =  77.81584661014585
# (Velocity, slope, shift): Cont-1 (speed) = (0.031489, 0.197392, 0.001594) | Cont-2 (shift) = (-0.100373, -0.044703, -0.003349)
# Categ-1 (angle) =  66.75232668312671 |Categ-2 (angle) =  77.75505109634358
# (Velocity, slope, shift): Cont-1 (speed) = (0.031360, 0.196177, 0.001566) | Cont-2 (shift) = (-0.100290, -0.044776, -0.003339)
# Categ-1 (angle) =  66.6075813142358 |Categ-2 (angle) =  77.62517504927578
# (Velocity, slope, shift): Cont-1 (speed) = (0.031360, 0.194968, 0.001550) | Cont-2 (shift) = (-0.100126, -0.044813, -0.003339)
# Categ-1 (angle) =  66.40354307316001 |Categ-2 (angle) =  77.38638480570297
# (Velocity, slope, shift): Cont-1 (speed) = (0.031326, 0.193790, 0.001532) | Cont-2 (shift) = (-0.099866, -0.044848, -0.003336)
# Categ-1 (angle) =  66.18916392568083 |Categ-2 (angle) =  77.12954920234299
# (Velocity, slope, shift): Cont-1 (speed) = (0.031209, 0.192613, 0.001509) | Cont-2 (shift) = (-0.099476, -0.044923, -0.003330)
# Categ-1 (angle) =  65.97196391007442 |Categ-2 (angle) =  76.86744069294375
# (Velocity, slope, shift): Cont-1 (speed) = (0.031112, 0.191440, 0.001489) | Cont-2 (shift) = (-0.099146, -0.045030, -0.003327)
# Categ-1 (angle) =  65.7623522346359 |Categ-2 (angle) =  76.61629463716237
# (Velocity, slope, shift): Cont-1 (speed) = (0.031007, 0.190259, 0.001471) | Cont-2 (shift) = (-0.098876, -0.045222, -0.003326)
# Categ-1 (angle) =  65.55554776694625 |Categ-2 (angle) =  76.37017560061012
# (Velocity, slope, shift): Cont-1 (speed) = (0.030992, 0.189058, 0.001457) | Cont-2 (shift) = (-0.098623, -0.045647, -0.003326)
# Categ-1 (angle) =  65.35601745072267 |Categ-2 (angle) =  76.16072101952253
# (Velocity, slope, shift): Cont-1 (speed) = (0.031046, 0.187746, 0.001450) | Cont-2 (shift) = (-0.098364, -0.042796, -0.003327)
# Categ-1 (angle) =  65.14919932265468 |Categ-2 (angle) =  76.03048297242871
# (Velocity, slope, shift): Cont-1 (speed) = (0.030986, 0.186664, 0.001429) | Cont-2 (shift) = (-0.097950, -0.042936, -0.003316)
# Categ-1 (angle) =  64.95445696903928 |Categ-2 (angle) =  75.78168650172184
# (Velocity, slope, shift): Cont-1 (speed) = (0.030715, 0.185613, 0.001400) | Cont-2 (shift) = (-0.097457, -0.042872, -0.003299)
# Categ-1 (angle) =  64.75748114356529 |Categ-2 (angle) =  75.53446780471322
# (Velocity, slope, shift): Cont-1 (speed) = (0.030432, 0.184565, 0.001367) | Cont-2 (shift) = (-0.096975, -0.042810, -0.003274)
# Categ-1 (angle) =  64.5525754684649 |Categ-2 (angle) =  75.28355397536363
# (Velocity, slope, shift): Cont-1 (speed) = (0.030155, 0.183518, 0.001333) | Cont-2 (shift) = (-0.096563, -0.042753, -0.003249)
# Categ-1 (angle) =  64.34923390668445 |Categ-2 (angle) =  75.03552931603296
# (Velocity, slope, shift): Cont-1 (speed) = (0.029878, 0.182486, 0.001300) | Cont-2 (shift) = (-0.096297, -0.042678, -0.003232)
# Categ-1 (angle) =  64.14793457146584 |Categ-2 (angle) =  74.79096756261148
# (Velocity, slope, shift): Cont-1 (speed) = (0.029638, 0.181465, 0.001265) | Cont-2 (shift) = (-0.095949, -0.042613, -0.003217)
# Categ-1 (angle) =  63.9483018024047 |Categ-2 (angle) =  74.54775818664567
# (Velocity, slope, shift): Cont-1 (speed) = (0.029386, 0.180455, 0.001230) | Cont-2 (shift) = (-0.095494, -0.042591, -0.003193)
# Categ-1 (angle) =  63.75157186374083 |Categ-2 (angle) =  74.30676179197094
# (Velocity, slope, shift): Cont-1 (speed) = (0.029103, 0.179477, 0.001194) | Cont-2 (shift) = (-0.095197, -0.042570, -0.003173)
# Categ-1 (angle) =  63.5558323025066 |Categ-2 (angle) =  74.06826524653243
# (Velocity, slope, shift): Cont-1 (speed) = (0.028768, 0.178509, 0.001153) | Cont-2 (shift) = (-0.094875, -0.042518, -0.003145)
# Categ-1 (angle) =  63.361752477240685 |Categ-2 (angle) =  73.83241198430272
# (Velocity, slope, shift): Cont-1 (speed) = (0.028446, 0.177548, 0.001111) | Cont-2 (shift) = (-0.094548, -0.042474, -0.003114)
# Categ-1 (angle) =  63.16995393515756 |Categ-2 (angle) =  73.59843702409476
# (Velocity, slope, shift): Cont-1 (speed) = (0.028092, 0.176572, 0.001073) | Cont-2 (shift) = (-0.094407, -0.042428, -0.003086)
# Categ-1 (angle) =  62.984268412381596 |Categ-2 (angle) =  73.37511032880286
# (Velocity, slope, shift): Cont-1 (speed) = (0.027780, 0.175550, 0.001047) | Cont-2 (shift) = (-0.094139, -0.042349, -0.003059)
# Categ-1 (angle) =  62.799163455685076 |Categ-2 (angle) =  73.15179046370012
# (Velocity, slope, shift): Cont-1 (speed) = (0.027509, 0.174526, 0.001027) | Cont-2 (shift) = (-0.093866, -0.042261, -0.003032)
# Categ-1 (angle) =  62.61315008382895 |Categ-2 (angle) =  72.92793784384213
# (Velocity, slope, shift): Cont-1 (speed) = (0.027530, 0.173524, 0.001014) | Cont-2 (shift) = (-0.093658, -0.042253, -0.003026)
# Categ-1 (angle) =  62.47233890389997 |Categ-2 (angle) =  72.73865964156273
# (Velocity, slope, shift): Cont-1 (speed) = (0.027532, 0.172511, 0.001004) | Cont-2 (shift) = (-0.093495, -0.042240, -0.003022)
# Categ-1 (angle) =  62.33897946035547 |Categ-2 (angle) =  72.55089774127909
# (Velocity, slope, shift): Cont-1 (speed) = (0.027576, 0.171509, 0.000995) | Cont-2 (shift) = (-0.093340, -0.042293, -0.003022)
# Categ-1 (angle) =  62.18970567604484 |Categ-2 (angle) =  72.3521665571884
# (Velocity, slope, shift): Cont-1 (speed) = (0.027473, 0.170541, 0.000974) | Cont-2 (shift) = (-0.092841, -0.042215, -0.002999)
# Categ-1 (angle) =  62.00871249322867 |Categ-2 (angle) =  72.13276039048007
# (Velocity, slope, shift): Cont-1 (speed) = (0.027539, 0.181487, 0.000960) | Cont-2 (shift) = (-0.092072, -0.039531, -0.002991)
# Categ-1 (angle) =  61.93373067652027 |Categ-2 (angle) =  72.0123783063586
# (Velocity, slope, shift): Cont-1 (speed) = (0.027591, 0.180536, 0.000946) | Cont-2 (shift) = (-0.091247, -0.039888, -0.002984)
# Categ-1 (angle) =  61.943040224358995 |Categ-2 (angle) =  71.95637075516449
# (Velocity, slope, shift): Cont-1 (speed) = (0.027609, 0.179740, 0.000938) | Cont-2 (shift) = (-0.090335, -0.039874, -0.002980)
# Categ-1 (angle) =  62.043163967402215 |Categ-2 (angle) =  71.98481166286842
# (Velocity, slope, shift): Cont-1 (speed) = (0.027623, 0.179102, 0.000934) | Cont-2 (shift) = (-0.089365, -0.040517, -0.002979)
# Categ-1 (angle) =  62.15180495634044 |Categ-2 (angle) =  72.00262479622381
# (Velocity, slope, shift): Cont-1 (speed) = (0.027513, 0.178116, 0.000914) | Cont-2 (shift) = (-0.088938, -0.040443, -0.002957)
# Categ-1 (angle) =  61.97817471744954 |Categ-2 (angle) =  71.79110749800687
# (Velocity, slope, shift): Cont-1 (speed) = (0.027401, 0.177148, 0.000895) | Cont-2 (shift) = (-0.088534, -0.040362, -0.002937)
# Categ-1 (angle) =  61.8051933465298 |Categ-2 (angle) =  71.58101087913727
# (Velocity, slope, shift): Cont-1 (speed) = (0.027291, 0.176188, 0.000878) | Cont-2 (shift) = (-0.088125, -0.040290, -0.002918)
# Categ-1 (angle) =  61.63294963604042 |Categ-2 (angle) =  71.3725261849118
# (Velocity, slope, shift): Cont-1 (speed) = (0.027184, 0.175229, 0.000861) | Cont-2 (shift) = (-0.087776, -0.040244, -0.002902)
# Categ-1 (angle) =  61.461122567090406 |Categ-2 (angle) =  71.16564658514129
# (Velocity, slope, shift): Cont-1 (speed) = (0.027303, 0.183124, 0.000863) | Cont-2 (shift) = (-0.086898, -0.038798, -0.002902)
# Categ-1 (angle) =  61.578506198166245 |Categ-2 (angle) =  71.14747828194905
# (Velocity, slope, shift): Cont-1 (speed) = (0.027218, 0.182122, 0.000853) | Cont-2 (shift) = (-0.086423, -0.038947, -0.002903)
# Categ-1 (angle) =  61.428528904371106 |Categ-2 (angle) =  70.9624074761984
# (Velocity, slope, shift): Cont-1 (speed) = (0.027134, 0.181129, 0.000842) | Cont-2 (shift) = (-0.086042, -0.038947, -0.002904)
# Categ-1 (angle) =  61.280518705056934 |Categ-2 (angle) =  70.78000044422403
# (Velocity, slope, shift): Cont-1 (speed) = (0.027084, 0.180164, 0.000831) | Cont-2 (shift) = (-0.085728, -0.038907, -0.002904)
# Categ-1 (angle) =  61.13434582662949 |Categ-2 (angle) =  70.59745680846626
# (Velocity, slope, shift): Cont-1 (speed) = (0.027077, 0.179207, 0.000822) | Cont-2 (shift) = (-0.085388, -0.038872, -0.002902)
# Categ-1 (angle) =  60.99309068440446 |Categ-2 (angle) =  70.41848536164441
# (Velocity, slope, shift): Cont-1 (speed) = (0.027083, 0.178249, 0.000813) | Cont-2 (shift) = (-0.085056, -0.038870, -0.002900)
# Categ-1 (angle) =  60.85665765573345 |Categ-2 (angle) =  70.24238259427398
# (Velocity, slope, shift): Cont-1 (speed) = (0.027010, 0.177291, 0.000796) | Cont-2 (shift) = (-0.084713, -0.038885, -0.002897)
# Categ-1 (angle) =  60.72129013657297 |Categ-2 (angle) =  70.06643009106529
# (Velocity, slope, shift): Cont-1 (speed) = (0.026948, 0.176343, 0.000781) | Cont-2 (shift) = (-0.084434, -0.038897, -0.002893)
# Categ-1 (angle) =  60.579058277296625 |Categ-2 (angle) =  69.88392743644255
# (Velocity, slope, shift): Cont-1 (speed) = (0.026871, 0.175422, 0.000767) | Cont-2 (shift) = (-0.084201, -0.038897, -0.002888)
# Categ-1 (angle) =  60.42850041742203 |Categ-2 (angle) =  69.69593330972711
# (Velocity, slope, shift): Cont-1 (speed) = (0.026852, 0.174511, 0.000756) | Cont-2 (shift) = (-0.084041, -0.038913, -0.002884)
# Categ-1 (angle) =  60.27277210434574 |Categ-2 (angle) =  69.50608137155744
# (Velocity, slope, shift): Cont-1 (speed) = (0.026859, 0.173582, 0.000749) | Cont-2 (shift) = (-0.083990, -0.038967, -0.002879)
# Categ-1 (angle) =  60.11577337608383 |Categ-2 (angle) =  69.31681682965639
# (Velocity, slope, shift): Cont-1 (speed) = (0.026678, 0.172834, 0.000738) | Cont-2 (shift) = (-0.083686, -0.038454, -0.002851)
# Categ-1 (angle) =  59.959464496928085 |Categ-2 (angle) =  69.13425270333111
# (Velocity, slope, shift): Cont-1 (speed) = (0.026523, 0.172076, 0.000723) | Cont-2 (shift) = (-0.083376, -0.038021, -0.002821)
# Categ-1 (angle) =  59.805423240576786 |Categ-2 (angle) =  68.95538370934682
# (Velocity, slope, shift): Cont-1 (speed) = (0.026375, 0.171310, 0.000706) | Cont-2 (shift) = (-0.083112, -0.037600, -0.002789)
# Categ-1 (angle) =  59.65300073905878 |Categ-2 (angle) =  68.77948584765149
# (Velocity, slope, shift): Cont-1 (speed) = (0.026245, 0.170543, 0.000686) | Cont-2 (shift) = (-0.082902, -0.037212, -0.002753)
# Categ-1 (angle) =  59.50148665270039 |Categ-2 (angle) =  68.60408658976556
# (Velocity, slope, shift): Cont-1 (speed) = (0.026121, 0.169783, 0.000666) | Cont-2 (shift) = (-0.082695, -0.036839, -0.002717)
# Categ-1 (angle) =  59.35083317017742 |Categ-2 (angle) =  68.42924740739157
# (Velocity, slope, shift): Cont-1 (speed) = (0.025979, 0.169033, 0.000647) | Cont-2 (shift) = (-0.082544, -0.036458, -0.002678)
# Categ-1 (angle) =  59.201805272676914 |Categ-2 (angle) =  68.25693539501049
# (Velocity, slope, shift): Cont-1 (speed) = (0.025806, 0.168289, 0.000630) | Cont-2 (shift) = (-0.082377, -0.036061, -0.002640)
# Categ-1 (angle) =  59.05337843182336 |Categ-2 (angle) =  68.08493757133122
# (Velocity, slope, shift): Cont-1 (speed) = (0.025651, 0.167550, 0.000612) | Cont-2 (shift) = (-0.082254, -0.035637, -0.002602)
# Categ-1 (angle) =  58.90691868545078 |Categ-2 (angle) =  67.91734521966661
# (Velocity, slope, shift): Cont-1 (speed) = (0.025440, 0.166827, 0.000598) | Cont-2 (shift) = (-0.082133, -0.035191, -0.002565)
# Categ-1 (angle) =  58.76236456185663 |Categ-2 (angle) =  67.75261471726425
# (Velocity, slope, shift): Cont-1 (speed) = (0.025245, 0.166113, 0.000585) | Cont-2 (shift) = (-0.082009, -0.034780, -0.002533)
# Categ-1 (angle) =  58.61760553258738 |Categ-2 (angle) =  67.58711240348568
# (Velocity, slope, shift): Cont-1 (speed) = (0.025023, 0.165408, 0.000573) | Cont-2 (shift) = (-0.081654, -0.034098, -0.002507)
# Categ-1 (angle) =  58.47209518250943 |Categ-2 (angle) =  67.41628254215449
# (Velocity, slope, shift): Cont-1 (speed) = (0.024858, 0.164697, 0.000558) | Cont-2 (shift) = (-0.081261, -0.033546, -0.002476)
# Categ-1 (angle) =  58.3282650589673 |Categ-2 (angle) =  67.24461939774456
# (Velocity, slope, shift): Cont-1 (speed) = (0.024708, 0.163997, 0.000544) | Cont-2 (shift) = (-0.080844, -0.033027, -0.002448)
# Categ-1 (angle) =  58.186040029880125 |Categ-2 (angle) =  67.07398078171013
# (Velocity, slope, shift): Cont-1 (speed) = (0.024623, 0.163243, 0.000533) | Cont-2 (shift) = (-0.080344, -0.033043, -0.002437)
# Categ-1 (angle) =  58.05802179426657 |Categ-2 (angle) =  66.91973461968372
# (Velocity, slope, shift): Cont-1 (speed) = (0.024499, 0.162498, 0.000520) | Cont-2 (shift) = (-0.079853, -0.033008, -0.002422)
# Categ-1 (angle) =  57.9225381618902 |Categ-2 (angle) =  66.75825528732629
# (Velocity, slope, shift): Cont-1 (speed) = (0.024361, 0.161766, 0.000504) | Cont-2 (shift) = (-0.079454, -0.032933, -0.002409)
# Categ-1 (angle) =  57.78318181225443 |Categ-2 (angle) =  66.59231584144082
# (Velocity, slope, shift): Cont-1 (speed) = (0.024209, 0.161049, 0.000483) | Cont-2 (shift) = (-0.079105, -0.032852, -0.002396)
# Categ-1 (angle) =  57.643791311672814 |Categ-2 (angle) =  66.42653348990628
# (Velocity, slope, shift): Cont-1 (speed) = (0.024281, 0.160353, 0.000480) | Cont-2 (shift) = (-0.078724, -0.034513, -0.002392)
# Categ-1 (angle) =  57.78307252922771 |Categ-2 (angle) =  66.42266077264688
# (Velocity, slope, shift): Cont-1 (speed) = (0.024348, 0.159697, 0.000477) | Cont-2 (shift) = (-0.078210, -0.040368, -0.002389)
# Categ-1 (angle) =  57.877028611450406 |Categ-2 (angle) =  66.41328292291645
# (Velocity, slope, shift): Cont-1 (speed) = (0.024391, 0.159022, 0.000474) | Cont-2 (shift) = (-0.077647, -0.042870, -0.002385)
# Categ-1 (angle) =  57.922831860024516 |Categ-2 (angle) =  66.37850359966275
# (Velocity, slope, shift): Cont-1 (speed) = (0.024383, 0.158255, 0.000469) | Cont-2 (shift) = (-0.077195, -0.043136, -0.002381)
# Categ-1 (angle) =  57.86174947827709 |Categ-2 (angle) =  66.2804152529922
# (Velocity, slope, shift): Cont-1 (speed) = (0.024337, 0.157510, 0.000457) | Cont-2 (shift) = (-0.076688, -0.043126, -0.002367)
# Categ-1 (angle) =  57.7691594338884 |Categ-2 (angle) =  66.1591042631436
# (Velocity, slope, shift): Cont-1 (speed) = (0.024262, 0.156783, 0.000445) | Cont-2 (shift) = (-0.076256, -0.043064, -0.002351)
# Categ-1 (angle) =  57.66384474707597 |Categ-2 (angle) =  66.02538964976226
# (Velocity, slope, shift): Cont-1 (speed) = (0.024204, 0.156053, 0.000430) | Cont-2 (shift) = (-0.075846, -0.043004, -0.002336)
# Categ-1 (angle) =  57.55764213567144 |Categ-2 (angle) =  65.89125156465238
# (Velocity, slope, shift): Cont-1 (speed) = (0.024027, 0.155368, 0.000414) | Cont-2 (shift) = (-0.075580, -0.042876, -0.002330)
# Categ-1 (angle) =  57.447116014522294 |Categ-2 (angle) =  65.75817215886386
# (Velocity, slope, shift): Cont-1 (speed) = (0.023787, 0.154679, 0.000392) | Cont-2 (shift) = (-0.075313, -0.042777, -0.002325)
# Categ-1 (angle) =  57.33632351599552 |Categ-2 (angle) =  65.62448486623919
# (Velocity, slope, shift): Cont-1 (speed) = (0.023470, 0.153971, 0.000366) | Cont-2 (shift) = (-0.074988, -0.042754, -0.002318)
# Categ-1 (angle) =  57.22248133800433 |Categ-2 (angle) =  65.48615304497892
# (Velocity, slope, shift): Cont-1 (speed) = (0.023438, 0.153855, 0.000345) | Cont-2 (shift) = (-0.074485, -0.042408, -0.002309)
# Categ-1 (angle) =  57.12010363253501 |Categ-2 (angle) =  65.35906371509249
# (Velocity, slope, shift): Cont-1 (speed) = (0.023332, 0.153274, 0.000330) | Cont-2 (shift) = (-0.074310, -0.042014, -0.002293)
# Categ-1 (angle) =  57.5347610019519 |Categ-2 (angle) =  65.69467189015025
# (Velocity, slope, shift): Cont-1 (speed) = (0.023134, 0.152670, 0.000322) | Cont-2 (shift) = (-0.074143, -0.041700, -0.002274)
# Categ-1 (angle) =  57.94653944663363 |Categ-2 (angle) =  66.03224715968895
# (Velocity, slope, shift): Cont-1 (speed) = (0.022972, 0.152067, 0.000311) | Cont-2 (shift) = (-0.073981, -0.041341, -0.002244)
# Categ-1 (angle) =  57.81859634310095 |Categ-2 (angle) =  65.88702367755614
# (Velocity, slope, shift): Cont-1 (speed) = (0.022864, 0.151480, 0.000299) | Cont-2 (shift) = (-0.073708, -0.040961, -0.002222)
# Categ-1 (angle) =  57.688781767735684 |Categ-2 (angle) =  65.73805725175816
# (Velocity, slope, shift): Cont-1 (speed) = (0.022757, 0.150888, 0.000287) | Cont-2 (shift) = (-0.073379, -0.040616, -0.002202)
# Categ-1 (angle) =  57.55950677731486 |Categ-2 (angle) =  65.58914546747354
# (Velocity, slope, shift): Cont-1 (speed) = (0.022679, 0.150285, 0.000271) | Cont-2 (shift) = (-0.073084, -0.040284, -0.002178)
# Categ-1 (angle) =  57.43090797562186 |Categ-2 (angle) =  65.44097134361928
# (Velocity, slope, shift): Cont-1 (speed) = (0.022569, 0.149685, 0.000258) | Cont-2 (shift) = (-0.072742, -0.039960, -0.002156)
# Categ-1 (angle) =  57.30299902303503 |Categ-2 (angle) =  65.29306359714266
# (Velocity, slope, shift): Cont-1 (speed) = (0.022420, 0.149088, 0.000247) | Cont-2 (shift) = (-0.072422, -0.039609, -0.002133)
# Categ-1 (angle) =  57.176643938484375 |Categ-2 (angle) =  65.14874853016946
# (Velocity, slope, shift): Cont-1 (speed) = (0.022253, 0.148528, 0.000238) | Cont-2 (shift) = (-0.072132, -0.039069, -0.002109)
# Categ-1 (angle) =  57.052112514442115 |Categ-2 (angle) =  65.00065636858524
# (Velocity, slope, shift): Cont-1 (speed) = (0.022114, 0.147967, 0.000228) | Cont-2 (shift) = (-0.071838, -0.038532, -0.002083)
# Categ-1 (angle) =  56.93044293966209 |Categ-2 (angle) =  64.85375949010579
# (Velocity, slope, shift): Cont-1 (speed) = (0.022275, 0.147619, 0.000232) | Cont-2 (shift) = (-0.071479, -0.034813, -0.002091)
# Categ-1 (angle) =  56.938270336450934 |Categ-2 (angle) =  64.78986307042031
# (Velocity, slope, shift): Cont-1 (speed) = (0.022185, 0.146981, 0.000223) | Cont-2 (shift) = (-0.071222, -0.034802, -0.002093)
# Categ-1 (angle) =  56.834485612012585 |Categ-2 (angle) =  64.66441298593469
# (Velocity, slope, shift): Cont-1 (speed) = (0.022127, 0.146353, 0.000216) | Cont-2 (shift) = (-0.071052, -0.034745, -0.002094)
# Categ-1 (angle) =  56.7319405669086 |Categ-2 (angle) =  64.53946833544765
# (Velocity, slope, shift): Cont-1 (speed) = (0.022061, 0.145723, 0.000208) | Cont-2 (shift) = (-0.070883, -0.034694, -0.002094)
# Categ-1 (angle) =  56.63084693700324 |Categ-2 (angle) =  64.4147764019599
# (Velocity, slope, shift): Cont-1 (speed) = (0.021986, 0.145099, 0.000200) | Cont-2 (shift) = (-0.070720, -0.034637, -0.002095)
# Categ-1 (angle) =  56.52823359000755 |Categ-2 (angle) =  64.2878851475594
# (Velocity, slope, shift): Cont-1 (speed) = (0.021909, 0.144469, 0.000190) | Cont-2 (shift) = (-0.070512, -0.034611, -0.002094)
# Categ-1 (angle) =  56.42607103549709 |Categ-2 (angle) =  64.16093242145637
# Total-Elapsed-Time 0 hour: 3 min: 11 sec
# Eval Time: 0 hour: 2 min: 60 sec
# ===== END -->> 'Data and Time: 23-03-24, 00:44:57 ( 0:02:36.465108 ) =====

# %%
# !cd ../. && python ./trainer_main.py \
--dataset univ \
--epochs 800 \
--batch-size 64 \
--latent-dim 10 \
--d-learning-rate 1E-3 \
--g-learning-rate 1E-4 \
--unrolling-steps 1 \
--hidden-size 64 \
--n-social-features 3 \
--n-graph-attention-heads 4 \
--model socialWays \
--n-lstm-layers 1 \
--scale-data True \
--social-attention True \
--graph True \
--new-criterion True \
--info-loss-weight 0.9 \
--n-disc-code 2 \
--n-cont-code 2 \
--model-name-append full-07-12 \
--code-eval True \
# --seed 1234
# Out:
# Using torch 2.0.1
# Is the GPU available? False
# Device cpu
# ===== START -->> Data and Time: 23-03-24, 03:04:27 ( Darwin - posix ) =====
# ----- printing args -----
# {   'batch_size': 64,
#     'c1h': False,
#     'code_eval': True,
#     'd_learning_rate': 0.001,
#     'dataset': 'univ',
#     'dataset_parser': 'socialWays',
#     'dataset_type': 'socialWays',
#     'epochs': 800,
#     'g_learning_rate': 0.0001,
#     'graph': True,
#     'hidden_size': 64,
#     'info_loss_weight': 0.9,
#     'l1o': False,
#     'lambda_cont_code': 0.1,
#     'lambda_disc_code': 0.1,
#     'latent_dim': 10,
#     'lstm_decoder': False,
#     'model': 'socialWays',
#     'model_name_append': 'full-07-12',
#     'n_cont_code': 2,
#     'n_disc_code': 2,
#     'n_graph_attention_heads': 4,
#     'n_lstm_layers': 1,
#     'n_social_features': 3,
#     'new_criterion': True,
#     'nll': False,
#     'scale_data': True,
#     'seed': 1234,
#     'social_attention': True,
#     'unrolling_steps': 1}
# --x-- printing args --x--
# Model File For Training:  ./TRAJ/trained_models/socialWays/univ_sg_22_34_800-bce-0.9_full-07-12_nec.pt
# Loading model from ./TRAJ/trained_models/socialWays/univ_sg_22_34_800-bce-0.9_full-07-12_nec.pt
# model trained on: 08-12-23, 18:31:15
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-0.npz  # Training samples:  11835
# ./TRAJ/processed/socialWays/univ-8-12-0.npz  # Test samples:  2460
# Batched Test Dataset Creation time: 0 hour: 0 min: 10 sec
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-1.npz  # Training samples:  9039
# ./TRAJ/processed/socialWays/univ-8-12-1.npz  # Test samples:  1000
# Batched Test Dataset Creation time: 0 hour: 0 min: 2 sec
# /Users/z.ahmed/workspace/DSProjects/trajectory-prediction
# ./TRAJ/processed/socialWays/univ-8-12-2.npz  # Training samples:  508
# ./TRAJ/processed/socialWays/univ-8-12-2.npz  # Test samples:  113
# Batched Test Dataset Creation time: 0 hour: 0 min: 1 sec
# Total Data Processing Time: 0 hour: 0 min: 11 sec
# Performing Code Evaluation on data...
# Categ-1 (angle) = ( -0.008373562627201033 | 0.16848372355662897 | 3.5209202553460837 ) | Categ-2 (dir) =  64.16093242145637 | 82.03988728804171 | 154.38455531936074
# cont-1 (speed) = ( -0.37084818580611184 | 0.7756534306519651 | 1.4414896219530526 ) | cont-2 (shift) =  -0.0021898210536592695 | -0.001493191446853886 | 0.0004263712932394507
# Total-Elapsed-Time 0 hour: 3 min: 9 sec
# Eval Time: 0 hour: 2 min: 58 sec
# ===== END -->> 'Data and Time: 23-03-24, 03:07:02 ( 0:02:34.920360 ) =====
